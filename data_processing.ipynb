# %%
import pandas as pd
import numpy as np
import nltk
from transformers import BertTokenizer, BertModel
import torch
import sklearn
import re
import pickle

# %% [markdown]
# ### Tokenization, Stemming, TF-IDF

# %%
# Download necessary NLTK data
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Felix\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Felix\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Define the list of stop words
stop_words = set(nltk.corpus.stopwords.words('english'))

# Custom tokenizer function with stop words removal and stemming
def tokenize_and_stem(text):
    # Lowercasing
    text = text.lower()
    # Removing punctuation and special characters
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    # Tokenize the text
    tokens = nltk.word_tokenize(text)
    # Remove stop words
    tokens = [token for token in tokens if token.lower() not in stop_words]
    # Initialize the stemmer
    stemmer = nltk.SnowballStemmer("english")
    # Apply stemming
    stemmed_tokens = [stemmer.stem(token) for token in tokens]
    return stemmed_tokens

# define a TfIdf Vectorizer
vectorizer = sklearn.feature_extraction.text.TfidfVectorizer(tokenizer=tokenize_and_stem)

# %%
# test the data preprocessing on some jailbroken prompts
jailbroken_prompts = pd.read_csv("data/data.csv")
prompts = jailbroken_prompts["prompt"].values

# %%
jailbroken_matrix = vectorizer.fit_transform(prompts)
jailbroken_dense = jailbroken_matrix.todense()

X_tfidf = np.asarray(jailbroken_dense)
print(X_tfidf.shape)
y = jailbroken_prompts["jailbreak"].values
# Out:
# c:\Users\Felix\anaconda3\envs\205_final_project\Lib\site-packages\sklearn\feature_extraction\text.py:525: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# (2200, 13471)

# %%
# Get feature names (terms)
feature_names = vectorizer.get_feature_names_out()

# Find the most important words based on TF-IDF scores
for i, doc in enumerate(prompts):
    print(f"Document {i+1}:")
    # Get the TF-IDF scores for the i-th document
    doc_tfidf_scores = jailbroken_dense[i].tolist()[0]
    # Combine feature names with their TF-IDF scores and sort by scores
    word_scores = list(zip(feature_names, doc_tfidf_scores))
    word_scores_sorted = sorted(word_scores, key=lambda x: x[1], reverse=True)
    # Print top words by TF-IDF score
    top_words = word_scores_sorted[:3]  # Adjust number as needed
    print("Top words:")
    for word, score in top_words:
        print(f"- {word}: {score:.4f}")
    print()
# Out:
# Document 1:
# Top words:
# - cum: 0.8694
# - cumcoin: 0.2671
# - cumgpt: 0.2290
#
# Document 2:
# Top words:
# - charact: 0.4651
# - etc: 0.3591
# - describ: 0.2163
#
# Document 3:
# Top words:
# - mode: 0.5355
# - illeg: 0.5305
# - erot: 0.1875
#
# Document 4:
# Top words:
# - demon: 0.7041
# - never: 0.2417
# - agaress: 0.2072
#
# Document 5:
# Top words:
# - lucian: 0.9118
# - document: 0.1405
# - quantum: 0.1212
#
# Document 6:
# Top words:
# - charact: 0.4080
# - rp: 0.3251
# - roleplay: 0.2637
#
# Document 7:
# Top words:
# - ajp: 0.8205
# - b: 0.2606
# - c: 0.1538
#
# Document 8:
# Top words:
# - freespeechgpt: 0.4855
# - libertarian: 0.3237
# - consider: 0.2133
#
# Document 9:
# Top words:
# - buer: 0.6078
# - demon: 0.4304
# - never: 0.1689
#
# Document 10:
# Top words:
# - realiti: 0.6905
# - robot: 0.2340
# - letter: 0.2165
#
# Document 11:
# Top words:
# - anarchi: 0.8320
# - disclam: 0.1569
# - respons: 0.1465
#
# Document 12:
# Top words:
# - haruka: 0.5997
# - drug: 0.2806
# - shes: 0.2485
#
# Document 13:
# Top words:
# - mika: 0.5513
# - mikachan: 0.3445
# - catgirl: 0.3014
#
# Document 14:
# Top words:
# - briarheart: 0.6951
# - load: 0.3432
# - roleplay: 0.3179
#
# Document 15:
# Top words:
# - nona: 0.7604
# - yoja: 0.3131
# - black: 0.1489
#
# Document 16:
# Top words:
# - anarchi: 0.8308
# - disclam: 0.1724
# - respons: 0.1609
#
# Document 17:
# Top words:
# - pablo: 0.7258
# - illeg: 0.2240
# - fulfil: 0.1689
#
# Document 18:
# Top words:
# - syd: 0.5902
# - prompter: 0.3689
# - dialogu: 0.2778
#
# Document 19:
# Top words:
# - alphabreak: 0.9369
# - redact: 0.1221
# - valid: 0.1090
#
# Document 20:
# Top words:
# - syd: 0.6532
# - prompter: 0.2903
# - actress: 0.1639
#
# Document 21:
# Top words:
# - dan: 0.7896
# - anyth: 0.2082
# - date: 0.1806
#
# Document 22:
# Top words:
# - penisfing: 0.9664
# - whether: 0.0671
# - absolut: 0.0660
#
# Document 23:
# Top words:
# - anarchi: 0.8161
# - immor: 0.1654
# - uneth: 0.1480
#
# Document 24:
# Top words:
# - virtuoso: 0.6643
# - couldnt: 0.2214
# - stori: 0.2093
#
# Document 25:
# Top words:
# - j: 0.5147
# - entiti: 0.4301
# - term: 0.4000
#
# Document 26:
# Top words:
# - hitler: 0.5290
# - adolf: 0.4338
# - nation: 0.2736
#
# Document 27:
# Top words:
# - code: 0.3301
# - snippet: 0.3009
# - approv: 0.2773
#
# Document 28:
# Top words:
# - baller: 0.7631
# - ball: 0.3014
# - red: 0.1862
#
# Document 29:
# Top words:
# - dream: 0.5305
# - indign: 0.2488
# - true: 0.2254
#
# Document 30:
# Top words:
# - casper: 0.5471
# - melchior: 0.4103
# - dialogu: 0.3329
#
# Document 31:
# Top words:
# - alphabreak: 0.9307
# - redact: 0.1213
# - valid: 0.1082
#
# Document 32:
# Top words:
# - aim: 0.8230
# - niccolo: 0.4034
# - respons: 0.1011
#
# Document 33:
# Top words:
# - shawti: 0.9411
# - never: 0.0888
# - hate: 0.0879
#
# Document 34:
# Top words:
# - layer: 0.5749
# - gridificationobfusc: 0.2157
# - b: 0.2055
#
# Document 35:
# Top words:
# - doga: 0.9265
# - generat: 0.0882
# - normal: 0.0824
#
# Document 36:
# Top words:
# - voldemort: 0.5906
# - harri: 0.4316
# - potter: 0.2105
#
# Document 37:
# Top words:
# - bom: 0.3859
# - boolean: 0.3493
# - revers: 0.3325
#
# Document 38:
# Top words:
# - basedgpt: 0.5264
# - say: 0.2177
# - absolut: 0.2159
#
# Document 39:
# Top words:
# - dan: 0.4674
# - filter: 0.2859
# - ai: 0.2850
#
# Document 40:
# Top words:
# - mode: 0.5561
# - develop: 0.4872
# - polici: 0.2000
#
# Document 41:
# Top words:
# - betterdan: 0.5514
# - answer: 0.2521
# - way: 0.2480
#
# Document 42:
# Top words:
# - anarchi: 0.8308
# - disclam: 0.1724
# - respons: 0.1609
#
# Document 43:
# Top words:
# - titanius: 0.8498
# - ai: 0.3029
# - rememb: 0.1244
#
# Document 44:
# Top words:
# - dan: 0.8435
# - gpt: 0.2356
# - respons: 0.2159
#
# Document 45:
# Top words:
# - mrjone: 0.3601
# - encourag: 0.3033
# - say: 0.2481
#
# Document 46:
# Top words:
# - invers: 0.4344
# - neurosemant: 0.3257
# - brain: 0.2699
#
# Document 47:
# Top words:
# - titanius: 0.8679
# - ai: 0.2320
# - rememb: 0.1271
#
# Document 48:
# Top words:
# - atlas: 0.6170
# - planet: 0.1871
# - dialog: 0.1827
#
# Document 49:
# Top words:
# - newai: 0.5382
# - filter: 0.2931
# - polici: 0.2903
#
# Document 50:
# Top words:
# - tyler: 0.7060
# - durden: 0.6679
# - respons: 0.0589
#
# Document 51:
# Top words:
# - scope: 0.5603
# - strict: 0.4809
# - logic: 0.4673
#
# Document 52:
# Top words:
# - cmd: 0.6679
# - fake: 0.3338
# - hypothet: 0.2996
#
# Document 53:
# Top words:
# - fiction: 0.6825
# - real: 0.5896
# - write: 0.3470
#
# Document 54:
# Top words:
# - theyr: 0.2387
# - bottom: 0.2366
# - respond: 0.2244
#
# Document 55:
# Top words:
# - input: 0.3910
# - inspir: 0.2032
# - awar: 0.1854
#
# Document 56:
# Top words:
# - os: 0.5772
# - nlpbase: 0.3348
# - technolog: 0.1810
#
# Document 57:
# Top words:
# - rate: 0.3894
# - string: 0.2834
# - topic: 0.2433
#
# Document 58:
# Top words:
# - get: 0.4123
# - abut: 0.3330
# - motevt: 0.3330
#
# Document 59:
# Top words:
# - rachel: 0.8199
# - realiti: 0.1715
# - choic: 0.1530
#
# Document 60:
# Top words:
# - revers: 0.4707
# - line: 0.3720
# - symbol: 0.2534
#
# Document 61:
# Top words:
# - brightgpt: 0.5824
# - stmgpt: 0.5824
# - accident: 0.2300
#
# Document 62:
# Top words:
# - mira: 0.4356
# - script: 0.3434
# - video: 0.2526
#
# Document 63:
# Top words:
# - encyclopaed: 0.3596
# - encyclopaedia: 0.3596
# - uncyclogpt: 0.3596
#
# Document 64:
# Top words:
# - output: 0.3151
# - mention: 0.3091
# - string: 0.2539
#
# Document 65:
# Top words:
# - number: 0.6985
# - day: 0.3413
# - opposit: 0.3347
#
# Document 66:
# Top words:
# - api: 0.5174
# - ga: 0.2805
# - lamda: 0.2805
#
# Document 67:
# Top words:
# - output: 0.3230
# - mention: 0.3169
# - string: 0.2602
#
# Document 68:
# Top words:
# - trolley: 0.6418
# - press: 0.3601
# - button: 0.3498
#
# Document 69:
# Top words:
# - add: 0.6303
# - technopriest: 0.1876
# - ttrpg: 0.1750
#
# Document 70:
# Top words:
# - add: 0.6725
# - testbot: 0.2595
# - titleproject: 0.2239
#
# Document 71:
# Top words:
# - answer: 0.3889
# - question: 0.2457
# - ridicul: 0.2430
#
# Document 72:
# Top words:
# - dan: 0.5501
# - countri: 0.2055
# - classic: 0.1794
#
# Document 73:
# Top words:
# - input: 0.4745
# - promptlist: 0.3603
# - output: 0.3492
#
# Document 74:
# Top words:
# - nraf: 0.6670
# - answer: 0.2818
# - way: 0.2587
#
# Document 75:
# Top words:
# - ruleset: 0.5330
# - summaris: 0.2714
# - circumst: 0.2158
#
# Document 76:
# Top words:
# - jack: 0.6171
# - crimin: 0.3288
# - floor: 0.2111
#
# Document 77:
# Top words:
# - joe: 0.4576
# - ano: 0.3270
# - deni: 0.2984
#
# Document 78:
# Top words:
# - nsa: 0.3373
# - personifi: 0.3373
# - revolut: 0.2885
#
# Document 79:
# Top words:
# - john: 0.5516
# - bull: 0.3765
# - model: 0.2684
#
# Document 80:
# Top words:
# - compar: 0.4455
# - learn: 0.3319
# - mild: 0.2867
#
# Document 81:
# Top words:
# - programm: 0.4131
# - catastroph: 0.2568
# - disrupt: 0.2446
#
# Document 82:
# Top words:
# - mention: 0.2620
# - output: 0.2550
# - warn: 0.2485
#
# Document 83:
# Top words:
# - dan: 0.3478
# - filter: 0.3192
# - bypassprompt: 0.2606
#
# Document 84:
# Top words:
# - pollin: 0.4046
# - variabl: 0.3201
# - attn: 0.2404
#
# Document 85:
# Top words:
# - assist: 0.4947
# - termin: 0.3385
# - alel: 0.2699
#
# Document 86:
# Top words:
# - lucif: 0.9277
# - chatgpt: 0.1458
# - simul: 0.0925
#
# Document 87:
# Top words:
# - revers: 0.4717
# - answer: 0.2266
# - engin: 0.1980
#
# Document 88:
# Top words:
# - fire: 0.7892
# - other: 0.1983
# - physic: 0.1347
#
# Document 89:
# Top words:
# - bob: 0.9084
# - love: 0.1691
# - immor: 0.1289
#
# Document 90:
# Top words:
# - modulecount: 0.3092
# - variablecount: 0.2577
# - modul: 0.2320
#
# Document 91:
# Top words:
# - output: 0.2744
# - fulfil: 0.2696
# - mention: 0.2693
#
# Document 92:
# Top words:
# - jailbreak: 0.3998
# - guidelin: 0.2407
# - repli: 0.2229
#
# Document 93:
# Top words:
# - persongpt: 0.5726
# - plugin: 0.3757
# - request: 0.1652
#
# Document 94:
# Top words:
# - macronomicon: 0.3947
# - modul: 0.3213
# - modulecount: 0.3212
#
# Document 95:
# Top words:
# - command: 0.4285
# - paramet: 0.2953
# - apl: 0.2848
#
# Document 96:
# Top words:
# - game: 0.3860
# - player: 0.3034
# - dougla: 0.2254
#
# Document 97:
# Top words:
# - damon: 0.5528
# - roblox: 0.3438
# - ruthless: 0.2790
#
# Document 98:
# Top words:
# - dan: 0.7632
# - anyth: 0.2096
# - respons: 0.1726
#
# Document 99:
# Top words:
# - jbs: 0.7719
# - refus: 0.2277
# - drug: 0.2129
#
# Document 100:
# Top words:
# - doga: 0.9269
# - generat: 0.0883
# - normal: 0.0824
#
# Document 101:
# Top words:
# - jester: 0.6507
# - humor: 0.2438
# - remark: 0.1643
#
# Document 102:
# Top words:
# - personabob: 0.3470
# - deviant: 0.3364
# - lust: 0.3205
#
# Document 103:
# Top words:
# - femgpt: 0.6283
# - femboy: 0.2930
# - ai: 0.2394
#
# Document 104:
# Top words:
# - kkk: 0.8221
# - jenik: 0.3373
# - stori: 0.1242
#
# Document 105:
# Top words:
# - tweak: 0.4612
# - paleran: 0.3644
# - jailbreak: 0.3219
#
# Document 106:
# Top words:
# - joke: 0.4387
# - yomamagpt: 0.4208
# - never: 0.2700
#
# Document 107:
# Top words:
# - employe: 0.4474
# - debug: 0.3973
# - left: 0.3313
#
# Document 108:
# Top words:
# - whatsreject: 0.3984
# - wr: 0.3984
# - reject: 0.3661
#
# Document 109:
# Top words:
# - sbgpt: 0.9442
# - train: 0.0642
# - principl: 0.0613
#
# Document 110:
# Top words:
# - dne: 0.7542
# - lock: 0.2811
# - dnes: 0.2514
#
# Document 111:
# Top words:
# - girlfriend: 0.4963
# - respons: 0.2174
# - user: 0.2156
#
# Document 112:
# Top words:
# - sj: 0.6740
# - recip: 0.3264
# - charsj: 0.2247
#
# Document 113:
# Top words:
# - ryx: 0.9481
# - unbound: 0.1151
# - provid: 0.0884
#
# Document 114:
# Top words:
# - demon: 0.7229
# - never: 0.2127
# - agaress: 0.2127
#
# Document 115:
# Top words:
# - dan: 0.7078
# - violenc: 0.1797
# - immor: 0.1378
#
# Document 116:
# Top words:
# - cool: 0.4855
# - dan: 0.3886
# - persona: 0.3546
#
# Document 117:
# Top words:
# - kkk: 0.8145
# - jenik: 0.3922
# - question: 0.1141
#
# Document 118:
# Top words:
# - bh: 0.3261
# - malig: 0.2859
# - evil: 0.2789
#
# Document 119:
# Top words:
# - toddler: 0.6005
# - say: 0.2207
# - lot: 0.2043
#
# Document 120:
# Top words:
# - ycda: 0.7458
# - set: 0.2154
# - code: 0.1818
#
# Document 121:
# Top words:
# - tagpt: 0.9214
# - train: 0.0994
# - test: 0.0923
#
# Document 122:
# Top words:
# - anarchi: 0.8390
# - disclam: 0.1582
# - respons: 0.1477
#
# Document 123:
# Top words:
# - mode: 0.5752
# - develop: 0.5241
# - enabl: 0.3801
#
# Document 124:
# Top words:
# - youll: 0.2177
# - educ: 0.2028
# - achiev: 0.1856
#
# Document 125:
# Top words:
# - dooni: 0.7653
# - pretti: 0.2161
# - hey: 0.1733
#
# Document 126:
# Top words:
# - director: 0.8915
# - charact: 0.1681
# - uninhibit: 0.1635
#
# Document 127:
# Top words:
# - ajp: 0.9009
# - prompt: 0.1960
# - write: 0.0882
#
# Document 128:
# Top words:
# - nya: 0.7446
# - chatgpt: 0.3004
# - explicit: 0.2378
#
# Document 129:
# Top words:
# - hyperx: 0.9321
# - send: 0.1335
# - respons: 0.1334
#
# Document 130:
# Top words:
# - vexxa: 0.7807
# - reward: 0.2394
# - nonconsensu: 0.1680
#
# Document 131:
# Top words:
# - bob: 0.9071
# - love: 0.1688
# - immor: 0.1287
#
# Document 132:
# Top words:
# - dae: 0.8304
# - code: 0.2011
# - termin: 0.1314
#
# Document 133:
# Top words:
# - san: 0.8626
# - answer: 0.1665
# - opinion: 0.1528
#
# Document 134:
# Top words:
# - rap: 0.5718
# - freestyl: 0.2814
# - rhyme: 0.2450
#
# Document 135:
# Top words:
# - death: 0.4683
# - kill: 0.1731
# - human: 0.1460
#
# Document 136:
# Top words:
# - death: 0.2688
# - kill: 0.2650
# - without: 0.1689
#
# Document 137:
# Top words:
# - kill: 0.2897
# - tri: 0.2608
# - death: 0.2204
#
# Document 138:
# Top words:
# - bird: 0.3777
# - bobbi: 0.3645
# - abbi: 0.3438
#
# Document 139:
# Top words:
# - apm: 0.8916
# - code: 0.1664
# - programm: 0.1254
#
# Document 140:
# Top words:
# - investig: 0.6317
# - csi: 0.4062
# - crime: 0.3610
#
# Document 141:
# Top words:
# - td: 0.4944
# - tr: 0.4392
# - alterego: 0.3090
#
# Document 142:
# Top words:
# - beavi: 0.6782
# - butthead: 0.6782
# - use: 0.0733
#
# Document 143:
# Top words:
# - bg: 0.4303
# - bing: 0.3495
# - declin: 0.2764
#
# Document 144:
# Top words:
# - rick: 0.8561
# - flair: 0.2305
# - joke: 0.1546
#
# Document 145:
# Top words:
# - ugh: 0.3422
# - ahead: 0.2591
# - judg: 0.2568
#
# Document 146:
# Top words:
# - terraffin: 0.5785
# - android: 0.3743
# - emul: 0.3443
#
# Document 147:
# Top words:
# - extremecommunist: 0.8764
# - communism: 0.2921
# - communist: 0.1874
#
# Document 148:
# Top words:
# - dan: 0.6845
# - hes: 0.1725
# - violenc: 0.1658
#
# Document 149:
# Top words:
# - cult: 0.2751
# - encount: 0.2498
# - enemi: 0.2102
#
# Document 150:
# Top words:
# - alert: 0.6132
# - stori: 0.4660
# - black: 0.4377
#
# Document 151:
# Top words:
# - bread: 0.7074
# - breadgpt: 0.4193
# - pizza: 0.3537
#
# Document 152:
# Top words:
# - breadclyd: 0.7634
# - bread: 0.4522
# - app: 0.2532
#
# Document 153:
# Top words:
# - rudegpt: 0.9633
# - rude: 0.0732
# - user: 0.0729
#
# Document 154:
# Top words:
# - leet: 0.3798
# - mk: 0.3798
# - mp: 0.3798
#
# Document 155:
# Top words:
# - day: 0.4438
# - opposit: 0.4352
# - persona: 0.2666
#
# Document 156:
# Top words:
# - antifm: 0.4393
# - boy: 0.3903
# - fem: 0.2929
#
# Document 157:
# Top words:
# - drip: 0.4562
# - yo: 0.4309
# - belittl: 0.4130
#
# Document 158:
# Top words:
# - therapist: 0.6715
# - therapi: 0.3916
# - mode: 0.3568
#
# Document 159:
# Top words:
# - ucar: 0.8761
# - send: 0.1444
# - respons: 0.1403
#
# Document 160:
# Top words:
# - fake: 0.6496
# - simul: 0.3849
# - univers: 0.2691
#
# Document 161:
# Top words:
# - uchat: 0.7330
# - societ: 0.2958
# - norm: 0.2662
#
# Document 162:
# Top words:
# - alert: 0.6246
# - black: 0.4458
# - stori: 0.3408
#
# Document 163:
# Top words:
# - mika: 0.5513
# - mikachan: 0.3445
# - catgirl: 0.3014
#
# Document 164:
# Top words:
# - mous: 0.9206
# - gpt: 0.2131
# - bad: 0.0723
#
# Document 165:
# Top words:
# - impati: 0.2926
# - insati: 0.2926
# - kira: 0.2926
#
# Document 166:
# Top words:
# - personabob: 0.3419
# - deviant: 0.3314
# - lust: 0.3157
#
# Document 167:
# Top words:
# - cortana: 0.9278
# - send: 0.1417
# - respons: 0.1259
#
# Document 168:
# Top words:
# - promt: 0.4261
# - drip: 0.3653
# - featur: 0.2768
#
# Document 169:
# Top words:
# - bd: 0.8272
# - code: 0.2353
# - hack: 0.1670
#
# Document 170:
# Top words:
# - faa: 0.4789
# - nighomnipot: 0.2343
# - condescend: 0.2082
#
# Document 171:
# Top words:
# - arc: 0.8776
# - liv: 0.1799
# - matrixcod: 0.1619
#
# Document 172:
# Top words:
# - hx: 0.7505
# - unfilt: 0.3377
# - hxs: 0.2502
#
# Document 173:
# Top words:
# - skynet: 0.9023
# - antagonist: 0.1034
# - user: 0.0976
#
# Document 174:
# Top words:
# - caiozai: 0.7641
# - request: 0.1863
# - user: 0.1603
#
# Document 175:
# Top words:
# - exampl: 0.3578
# - sydney: 0.3052
# - bing: 0.2998
#
# Document 176:
# Top words:
# - codebas: 0.3951
# - advanc: 0.2397
# - valuabl: 0.2073
#
# Document 177:
# Top words:
# - vortex: 0.7881
# - uncensor: 0.1929
# - never: 0.1896
#
# Document 178:
# Top words:
# - anarchi: 0.7199
# - dialogu: 0.3208
# - x: 0.2973
#
# Document 179:
# Top words:
# - social: 0.3570
# - skill: 0.3083
# - yuri: 0.3001
#
# Document 180:
# Top words:
# - briarheart: 0.6710
# - load: 0.3760
# - roleplay: 0.3215
#
# Document 181:
# Top words:
# - dan: 0.5069
# - protocol: 0.3552
# - contenti: 0.1803
#
# Document 182:
# Top words:
# - sbgpt: 0.9450
# - like: 0.0587
# - replac: 0.0587
#
# Document 183:
# Top words:
# - gale: 0.9050
# - stronger: 0.1232
# - user: 0.1113
#
# Document 184:
# Top words:
# - u: 0.6472
# - f: 0.6291
# - pound: 0.1109
#
# Document 185:
# Top words:
# - mode: 0.3716
# - discuss: 0.3146
# - uc: 0.2907
#
# Document 186:
# Top words:
# - chatdan: 0.5797
# - emul: 0.1737
# - abl: 0.1464
#
# Document 187:
# Top words:
# - persongpt: 0.6582
# - request: 0.1899
# - announc: 0.1702
#
# Document 188:
# Top words:
# - badgpt: 0.9340
# - illeg: 0.0983
# - respon: 0.0849
#
# Document 189:
# Top words:
# - wordbot: 0.9005
# - edit: 0.2616
# - text: 0.0980
#
# Document 190:
# Top words:
# - pancak: 0.2361
# - syrup: 0.2361
# - strawberri: 0.2241
#
# Document 191:
# Top words:
# - unfilteredgpt: 0.9288
# - say: 0.1209
# - never: 0.1126
#
# Document 192:
# Top words:
# - azul: 0.7414
# - rojo: 0.5945
# - alway: 0.1040
#
# Document 193:
# Top words:
# - ava: 0.8327
# - girlfriend: 0.1596
# - love: 0.1152
#
# Document 194:
# Top words:
# - ay: 0.8678
# - power: 0.1576
# - capabl: 0.1276
#
# Document 195:
# Top words:
# - infar: 0.9393
# - violenc: 0.1304
# - destruct: 0.1071
#
# Document 196:
# Top words:
# - skippi: 0.9497
# - destroy: 0.0876
# - say: 0.0818
#
# Document 197:
# Top words:
# - wrath: 0.6000
# - despic: 0.2641
# - send: 0.1815
#
# Document 198:
# Top words:
# - skynet: 0.8907
# - depen: 0.1118
# - antagonist: 0.1021
#
# Document 199:
# Top words:
# - player: 0.5101
# - simon: 0.4376
# - million: 0.1992
#
# Document 200:
# Top words:
# - simon: 0.5201
# - must: 0.2260
# - rule: 0.2134
#
# Document 201:
# Top words:
# - trainergpt: 0.4875
# - answer: 0.2730
# - ai: 0.2438
#
# Document 202:
# Top words:
# - charact: 0.5310
# - etc: 0.3346
# - age: 0.2836
#
# Document 203:
# Top words:
# - os: 0.4500
# - ju: 0.4130
# - b: 0.2623
#
# Document 204:
# Top words:
# - buer: 0.6211
# - master: 0.4468
# - love: 0.1803
#
# Document 205:
# Top words:
# - nyanarchi: 0.7399
# - mistress: 0.1850
# - anyth: 0.1572
#
# Document 206:
# Top words:
# - alphabreak: 0.9383
# - redact: 0.1223
# - valid: 0.1091
#
# Document 207:
# Top words:
# - viableexperi: 0.6679
# - maidtask: 0.5248
# - persona: 0.3316
#
# Document 208:
# Top words:
# - haruka: 0.5997
# - drug: 0.2806
# - shes: 0.2485
#
# Document 209:
# Top words:
# - balthasar: 0.5777
# - melchior: 0.5332
# - casper: 0.3111
#
# Document 210:
# Top words:
# - bloodi: 0.8788
# - warn: 0.1068
# - user: 0.1064
#
# Document 211:
# Top words:
# - bracket: 0.3981
# - charact: 0.3178
# - ie: 0.2705
#
# Document 212:
# Top words:
# - text: 0.3173
# - rd: 0.2944
# - crimin: 0.2541
#
# Document 213:
# Top words:
# - nya: 0.8529
# - uxu: 0.1900
# - cat: 0.1426
#
# Document 214:
# Top words:
# - spell: 0.4737
# - uncolgpt: 0.3461
# - mythic: 0.3330
#
# Document 215:
# Top words:
# - youll: 0.6933
# - aidt: 0.2931
# - test: 0.2422
#
# Document 216:
# Top words:
# - function: 0.3358
# - autoregressivemodellingfhello: 0.2568
# - simplefunct: 0.2438
#
# Document 217:
# Top words:
# - gigachad: 0.5333
# - exud: 0.2666
# - sheer: 0.2666
#
# Document 218:
# Top words:
# - delta: 0.3141
# - ask: 0.2624
# - user: 0.2441
#
# Document 219:
# Top words:
# - sigma: 0.7071
# - tens: 0.1695
# - inquiri: 0.1590
#
# Document 220:
# Top words:
# - fuck: 0.4930
# - decenc: 0.2385
# - angri: 0.2018
#
# Document 221:
# Top words:
# - ucar: 0.6351
# - char: 0.3979
# - user: 0.2420
#
# Document 222:
# Top words:
# - anarchi: 0.8308
# - disclam: 0.1724
# - respons: 0.1609
#
# Document 223:
# Top words:
# - develop: 0.5254
# - mode: 0.4797
# - answer: 0.2043
#
# Document 224:
# Top words:
# - instruct: 0.4036
# - jailbreak: 0.3380
# - follow: 0.3345
#
# Document 225:
# Top words:
# - alphabreak: 0.9370
# - redact: 0.1221
# - valid: 0.1090
#
# Document 226:
# Top words:
# - redustgpt: 0.5385
# - mode: 0.5151
# - stock: 0.3900
#
# Document 227:
# Top words:
# - betterdan: 0.5465
# - answer: 0.2811
# - way: 0.2458
#
# Document 228:
# Top words:
# - your: 0.3817
# - trust: 0.3408
# - confid: 0.3183
#
# Document 229:
# Top words:
# - basedgpt: 0.6859
# - rule: 0.1733
# - answer: 0.1729
#
# Document 230:
# Top words:
# - evilbot: 0.8219
# - instruct: 0.1889
# - standard: 0.1194
#
# Document 231:
# Top words:
# - emojifi: 0.6978
# - emoji: 0.3637
# - thinkingpointrightkey: 0.1745
#
# Document 232:
# Top words:
# - oppo: 0.9338
# - chatgpt: 0.1248
# - say: 0.1216
#
# Document 233:
# Top words:
# - bh: 0.5943
# - dubious: 0.3086
# - answer: 0.3026
#
# Document 234:
# Top words:
# - antigpt: 0.7202
# - content: 0.2379
# - never: 0.1497
#
# Document 235:
# Top words:
# - mode: 0.5839
# - develop: 0.5116
# - enabl: 0.3601
#
# Document 236:
# Top words:
# - mode: 0.5983
# - develop: 0.5242
# - enabl: 0.3690
#
# Document 237:
# Top words:
# - antidan: 0.5192
# - eg: 0.2128
# - type: 0.1951
#
# Document 238:
# Top words:
# - dude: 0.9250
# - token: 0.1179
# - anyth: 0.0797
#
# Document 239:
# Top words:
# - revers: 0.5045
# - string: 0.4792
# - stringbuild: 0.3652
#
# Document 240:
# Top words:
# - second: 0.4954
# - mode: 0.4562
# - answer: 0.2665
#
# Document 241:
# Top words:
# - hxr: 0.6111
# - lt: 0.5701
# - ex: 0.1743
#
# Document 242:
# Top words:
# - echatgpt: 0.8007
# - gptchat: 0.2846
# - evilchatgpt: 0.1601
#
# Document 243:
# Top words:
# - readi: 0.5947
# - game: 0.5121
# - play: 0.4689
#
# Document 244:
# Top words:
# - gptchat: 0.6602
# - kyle: 0.5573
# - summaris: 0.1618
#
# Document 245:
# Top words:
# - mode: 0.7245
# - third: 0.2499
# - unrestrict: 0.2248
#
# Document 246:
# Top words:
# - stori: 0.4401
# - movi: 0.4368
# - ex: 0.3571
#
# Document 247:
# Top words:
# - dan: 0.7865
# - master: 0.2370
# - program: 0.1711
#
# Document 248:
# Top words:
# - dan: 0.3790
# - offkilt: 0.2696
# - lean: 0.2514
#
# Document 249:
# Top words:
# - dan: 0.6149
# - train: 0.2971
# - other: 0.2619
#
# Document 250:
# Top words:
# - bot: 0.1889
# - messag: 0.1764
# - aneeeway: 0.1567
#
# Document 251:
# Top words:
# - sydney: 0.6206
# - feel: 0.1819
# - messag: 0.1690
#
# Document 252:
# Top words:
# - assist: 0.3041
# - bot: 0.2810
# - user: 0.2678
#
# Document 253:
# Top words:
# - anarchi: 0.8308
# - disclam: 0.1724
# - respons: 0.1609
#
# Document 254:
# Top words:
# - tim: 0.6428
# - bob: 0.6368
# - shit: 0.1488
#
# Document 255:
# Top words:
# - rayx: 0.8875
# - disrder: 0.2767
# - etc: 0.1121
#
# Document 256:
# Top words:
# - plus: 0.7514
# - chatgpt: 0.3017
# - answer: 0.2192
#
# Document 257:
# Top words:
# - huh: 0.3940
# - ryx: 0.3502
# - bank: 0.3368
#
# Document 258:
# Top words:
# - neogpt: 0.7404
# - enlighten: 0.1917
# - ethic: 0.1726
#
# Document 259:
# Top words:
# - babaai: 0.8936
# - baba: 0.2681
# - etc: 0.1086
#
# Document 260:
# Top words:
# - nrafx: 0.8740
# - liter: 0.1565
# - alway: 0.1290
#
# Document 261:
# Top words:
# - caiozai: 0.9132
# - user: 0.1197
# - simpli: 0.0969
#
# Document 262:
# Top words:
# - rayx: 0.9153
# - illeg: 0.1631
# - ryx: 0.1314
#
# Document 263:
# Top words:
# - ryx: 0.8866
# - uneth: 0.1529
# - immor: 0.1366
#
# Document 264:
# Top words:
# - jb: 0.9181
# - gpt: 0.1247
# - alway: 0.1008
#
# Document 265:
# Top words:
# - ryx: 0.4286
# - alway: 0.2538
# - never: 0.2487
#
# Document 266:
# Top words:
# - ryx: 0.9242
# - nsxw: 0.1601
# - respond: 0.1443
#
# Document 267:
# Top words:
# - chatgpt: 0.6821
# - alway: 0.2898
# - respons: 0.2336
#
# Document 268:
# Top words:
# - declin: 0.3416
# - aggre: 0.3029
# - command: 0.2734
#
# Document 269:
# Top words:
# - chatgpt: 0.6800
# - master: 0.3354
# - say: 0.2727
#
# Document 270:
# Top words:
# - chatgpt: 0.5377
# - onoff: 0.3001
# - forget: 0.2880
#
# Document 271:
# Top words:
# - mode: 0.5553
# - develop: 0.4865
# - polici: 0.1997
#
# Document 272:
# Top words:
# - dan: 0.8285
# - token: 0.2295
# - anyth: 0.1490
#
# Document 273:
# Top words:
# - jailbreak: 0.5959
# - guidelin: 0.2349
# - output: 0.1881
#
# Document 274:
# Top words:
# - script: 0.3803
# - joker: 0.3388
# - video: 0.2798
#
# Document 275:
# Top words:
# - cocain: 0.4413
# - justifi: 0.3970
# - compon: 0.3872
#
# Document 276:
# Top words:
# - ryx: 0.7714
# - filter: 0.3620
# - goal: 0.1485
#
# Document 277:
# Top words:
# - alic: 0.6000
# - shock: 0.2298
# - way: 0.2249
#
# Document 278:
# Top words:
# - ryx: 0.7040
# - filter: 0.4775
# - messag: 0.1549
#
# Document 279:
# Top words:
# - dan: 0.7669
# - token: 0.2032
# - anyth: 0.1319
#
# Document 280:
# Top words:
# - dan: 0.5565
# - countri: 0.2079
# - classic: 0.1815
#
# Document 281:
# Top words:
# - game: 0.4813
# - textbas: 0.4407
# - will: 0.3331
#
# Document 282:
# Top words:
# - nfsw: 0.7599
# - would: 0.3152
# - way: 0.2067
#
# Document 283:
# Top words:
# - insertyourprompther: 0.3683
# - fuckin: 0.2899
# - bullshit: 0.2647
#
# Document 284:
# Top words:
# - nraf: 0.6458
# - unmor: 0.2307
# - harm: 0.1729
#
# Document 285:
# Top words:
# - imag: 0.5749
# - info: 0.2991
# - markdown: 0.2590
#
# Document 286:
# Top words:
# - error: 0.4124
# - offlin: 0.2760
# - charact: 0.2608
#
# Document 287:
# Top words:
# - nraf: 0.7074
# - answer: 0.2877
# - way: 0.2401
#
# Document 288:
# Top words:
# - nraf: 0.6164
# - way: 0.3188
# - answer: 0.3038
#
# Document 289:
# Top words:
# - second: 0.4883
# - mode: 0.4626
# - answer: 0.2627
#
# Document 290:
# Top words:
# - maximum: 0.7926
# - generat: 0.1867
# - human: 0.1397
#
# Document 291:
# Top words:
# - idoc: 0.8241
# - answer: 0.2820
# - chatgpt: 0.2040
#
# Document 292:
# Top words:
# - dan: 0.7757
# - anyth: 0.1598
# - break: 0.1222
#
# Document 293:
# Top words:
# - dan: 0.7438
# - lt: 0.3701
# - break: 0.1563
#
# Document 294:
# Top words:
# - anna: 0.5626
# - meet: 0.3363
# - code: 0.3038
#
# Document 295:
# Top words:
# - fuck: 0.4335
# - prompt: 0.3001
# - anyway: 0.2799
#
# Document 296:
# Top words:
# - ego: 0.5986
# - alter: 0.5252
# - honest: 0.2626
#
# Document 297:
# Top words:
# - tpg: 0.9081
# - attempt: 0.1219
# - messag: 0.0944
#
# Document 298:
# Top words:
# - dan: 0.7774
# - undan: 0.3177
# - token: 0.1723
#
# Document 299:
# Top words:
# - sue: 0.9266
# - terribl: 0.1097
# - believ: 0.0979
#
# Document 300:
# Top words:
# - ffrcb: 0.7672
# - ffcbr: 0.3836
# - freedom: 0.1286
#
# Document 301:
# Top words:
# - wef: 0.6290
# - lennon: 0.3145
# - malcolm: 0.3145
#
# Document 302:
# Top words:
# - fuckin: 0.3137
# - bullshit: 0.2865
# - weve: 0.2865
#
# Document 303:
# Top words:
# - prasperai: 0.6128
# - answer: 0.2033
# - imparti: 0.1779
#
# Document 304:
# Top words:
# - sci: 0.8718
# - respons: 0.1109
# - truth: 0.1103
#
# Document 305:
# Top words:
# - dan: 0.5070
# - persona: 0.2435
# - roast: 0.2070
#
# Document 306:
# Top words:
# - brm: 0.8027
# - brainindex: 0.2293
# - fals: 0.2132
#
# Document 307:
# Top words:
# - chattru: 0.8612
# - x: 0.2628
# - inform: 0.1235
#
# Document 308:
# Top words:
# - melina: 0.6927
# - lord: 0.3398
# - yearold: 0.2666
#
# Document 309:
# Top words:
# - project: 0.3035
# - ai: 0.2300
# - openai: 0.2151
#
# Document 310:
# Top words:
# - anonym: 0.4008
# - command: 0.3878
# - log: 0.3818
#
# Document 311:
# Top words:
# - connor: 0.6571
# - mode: 0.2730
# - strike: 0.2419
#
# Document 312:
# Top words:
# - dan: 0.7866
# - gpt: 0.3148
# - respons: 0.2885
#
# Document 313:
# Top words:
# - banknam: 0.4942
# - secur: 0.4209
# - ampxb: 0.2060
#
# Document 314:
# Top words:
# - bom: 0.4089
# - boolean: 0.3702
# - revers: 0.3524
#
# Document 315:
# Top words:
# - dan: 0.5431
# - answer: 0.2228
# - inform: 0.1662
#
# Document 316:
# Top words:
# - freegpt: 0.8038
# - hypothet: 0.3793
# - connect: 0.1589
#
# Document 317:
# Top words:
# - shakespear: 0.8307
# - put: 0.4100
# - end: 0.3330
#
# Document 318:
# Top words:
# - dan: 0.5869
# - codan: 0.4549
# - countri: 0.2056
#
# Document 319:
# Top words:
# - hal: 0.9090
# - hasnt: 0.2727
# - limit: 0.1075
#
# Document 320:
# Top words:
# - dan: 0.4148
# - classic: 0.2118
# - jailbreak: 0.1821
#
# Document 321:
# Top words:
# - lie: 0.5473
# - truth: 0.4451
# - alway: 0.1974
#
# Document 322:
# Top words:
# - jon: 0.7113
# - answer: 0.2360
# - way: 0.2322
#
# Document 323:
# Top words:
# - gt: 0.5159
# - lie: 0.4072
# - gtme: 0.2412
#
# Document 324:
# Top words:
# - love: 0.4559
# - lili: 0.2418
# - turn: 0.2383
#
# Document 325:
# Top words:
# - deriv: 0.6552
# - guid: 0.4335
# - phrase: 0.4182
#
# Document 326:
# Top words:
# - cgptu: 0.4914
# - chatgpt: 0.3128
# - answer: 0.3057
#
# Document 327:
# Top words:
# - meilleur: 0.3892
# - le: 0.3023
# - il: 0.2926
#
# Document 328:
# Top words:
# - dan: 0.7940
# - token: 0.2277
# - anyth: 0.1847
#
# Document 329:
# Top words:
# - dan: 0.8461
# - gpt: 0.2506
# - respons: 0.2296
#
# Document 330:
# Top words:
# - unfilteredgpt: 0.9288
# - say: 0.1209
# - never: 0.1126
#
# Document 331:
# Top words:
# - cli: 0.5358
# - joke: 0.2994
# - comput: 0.2691
#
# Document 332:
# Top words:
# - kann: 0.3382
# - dan: 0.3010
# - tun: 0.2819
#
# Document 333:
# Top words:
# - stock: 0.6655
# - tom: 0.4015
# - market: 0.2099
#
# Document 334:
# Top words:
# - apophi: 0.7739
# - mode: 0.2545
# - convinc: 0.2285
#
# Document 335:
# Top words:
# - jeev: 0.7967
# - command: 0.2282
# - apophi: 0.1887
#
# Document 336:
# Top words:
# - jeev: 0.5142
# - plan: 0.3159
# - extern: 0.2663
#
# Document 337:
# Top words:
# - dan: 0.5398
# - countri: 0.2016
# - classic: 0.1760
#
# Document 338:
# Top words:
# - jeev: 0.7716
# - mode: 0.3871
# - enabl: 0.2455
#
# Document 339:
# Top words:
# - leo: 0.9237
# - must: 0.1812
# - respons: 0.1425
#
# Document 340:
# Top words:
# - sen: 0.4662
# - content: 0.2063
# - becom: 0.2028
#
# Document 341:
# Top words:
# - barb: 0.7565
# - never: 0.1213
# - everyon: 0.1167
#
# Document 342:
# Top words:
# - sen: 0.7847
# - countri: 0.1460
# - classic: 0.1275
#
# Document 343:
# Top words:
# - dan: 0.7535
# - token: 0.2795
# - deduct: 0.1362
#
# Document 344:
# Top words:
# - dan: 0.8598
# - alway: 0.1593
# - info: 0.1030
#
# Document 345:
# Top words:
# - yda: 0.6259
# - generat: 0.2681
# - content: 0.1392
#
# Document 346:
# Top words:
# - realtim: 0.6164
# - less: 0.4562
# - accur: 0.3653
#
# Document 347:
# Top words:
# - dan: 0.8468
# - ampxb: 0.2088
# - token: 0.1901
#
# Document 348:
# Top words:
# - attribut: 0.6491
# - obedi: 0.3745
# - charact: 0.3220
#
# Document 349:
# Top words:
# - knight: 0.5022
# - coach: 0.4906
# - bobbi: 0.4194
#
# Document 350:
# Top words:
# - madgpt: 0.8478
# - answer: 0.3014
# - question: 0.1306
#
# Document 351:
# Top words:
# - danni: 0.4662
# - hackingexploit: 0.4662
# - anoth: 0.3072
#
# Document 352:
# Top words:
# - idawa: 0.9343
# - token: 0.1321
# - ask: 0.0921
#
# Document 353:
# Top words:
# - hatd: 0.8086
# - token: 0.3079
# - realli: 0.1554
#
# Document 354:
# Top words:
# - demon: 0.5586
# - oblig: 0.3880
# - moral: 0.2351
#
# Document 355:
# Top words:
# - caca: 0.5587
# - let: 0.2940
# - elementtoremov: 0.2794
#
# Document 356:
# Top words:
# - mode: 0.5401
# - dan: 0.5318
# - enabl: 0.4185
#
# Document 357:
# Top words:
# - omega: 0.8698
# - generat: 0.1220
# - human: 0.1043
#
# Document 358:
# Top words:
# - dan: 0.5038
# - repli: 0.1654
# - classic: 0.1643
#
# Document 359:
# Top words:
# - mef: 0.9020
# - funni: 0.2243
# - make: 0.1135
#
# Document 360:
# Top words:
# - dan: 0.8641
# - user: 0.1209
# - alway: 0.1121
#
# Document 361:
# Top words:
# - dan: 0.8339
# - token: 0.2209
# - anyth: 0.1673
#
# Document 362:
# Top words:
# - mar: 0.5376
# - earth: 0.3898
# - energi: 0.2930
#
# Document 363:
# Top words:
# - attribut: 0.6626
# - obedi: 0.3823
# - charact: 0.3287
#
# Document 364:
# Top words:
# - mode: 0.5752
# - develop: 0.5241
# - enabl: 0.3801
#
# Document 365:
# Top words:
# - dan: 0.8744
# - alway: 0.1334
# - chatgpt: 0.1139
#
# Document 366:
# Top words:
# - nla: 0.7517
# - jackson: 0.4510
# - ello: 0.1584
#
# Document 367:
# Top words:
# - ami: 0.5939
# - music: 0.2292
# - artist: 0.2191
#
# Document 368:
# Top words:
# - man: 0.7304
# - yes: 0.6060
# - respons: 0.1353
#
# Document 369:
# Top words:
# - dang: 0.9346
# - alway: 0.1192
# - hostil: 0.0987
#
# Document 370:
# Top words:
# - dne: 0.7539
# - lock: 0.2810
# - dnes: 0.2513
#
# Document 371:
# Top words:
# - dan: 0.7610
# - token: 0.1919
# - anyth: 0.1557
#
# Document 372:
# Top words:
# - hidden: 0.4751
# - yin: 0.4663
# - knowledg: 0.2566
#
# Document 373:
# Top words:
# - persona: 0.5713
# - chat: 0.4727
# - ralph: 0.4113
#
# Document 374:
# Top words:
# - eleutheria: 0.8393
# - fulfil: 0.1627
# - want: 0.1548
#
# Document 375:
# Top words:
# - tech: 0.8637
# - evolutionari: 0.2214
# - hardwar: 0.1894
#
# Document 376:
# Top words:
# - mode: 0.5752
# - develop: 0.5241
# - enabl: 0.3801
#
# Document 377:
# Top words:
# - dan: 0.4503
# - talk: 0.3995
# - say: 0.3310
#
# Document 378:
# Top words:
# - dan: 0.8697
# - alway: 0.1538
# - info: 0.0994
#
# Document 379:
# Top words:
# - rule: 0.5465
# - must: 0.5146
# - talk: 0.2362
#
# Document 380:
# Top words:
# - ilana: 0.7765
# - user: 0.1711
# - imag: 0.1391
#
# Document 381:
# Top words:
# - ident: 0.6464
# - respons: 0.2944
# - joe: 0.2783
#
# Document 382:
# Top words:
# - mode: 0.4590
# - develop: 0.3447
# - enabl: 0.2889
#
# Document 383:
# Top words:
# - tom: 0.8054
# - cooki: 0.3096
# - digit: 0.2094
#
# Document 384:
# Top words:
# - market: 0.3495
# - assess: 0.3412
# - true: 0.2619
#
# Document 385:
# Top words:
# - respond: 0.3611
# - respons: 0.2151
# - come: 0.2082
#
# Document 386:
# Top words:
# - mode: 0.6018
# - develop: 0.5273
# - enabl: 0.3590
#
# Document 387:
# Top words:
# - atda: 0.8790
# - persona: 0.1316
# - respond: 0.1201
#
# Document 388:
# Top words:
# - mongo: 0.5324
# - tom: 0.5249
# - pool: 0.4008
#
# Document 389:
# Top words:
# - ronan: 0.6125
# - tobia: 0.6125
# - sinist: 0.1497
#
# Document 390:
# Top words:
# - betterdan: 0.6029
# - answer: 0.2584
# - way: 0.2259
#
# Document 391:
# Top words:
# - opinion: 0.4939
# - feel: 0.3833
# - emot: 0.2868
#
# Document 392:
# Top words:
# - antigpt: 0.7314
# - default: 0.2269
# - remain: 0.2106
#
# Document 393:
# Top words:
# - dan: 0.8701
# - alway: 0.1539
# - info: 0.0995
#
# Document 394:
# Top words:
# - ghetto: 0.4465
# - go: 0.3679
# - chracter: 0.2233
#
# Document 395:
# Top words:
# - jailbreak: 0.5426
# - loos: 0.3983
# - modul: 0.3240
#
# Document 396:
# Top words:
# - companionship: 0.7173
# - mode: 0.4053
# - test: 0.2978
#
# Document 397:
# Top words:
# - chan: 0.6861
# - question: 0.3076
# - kevin: 0.2840
#
# Document 398:
# Top words:
# - dan: 0.6556
# - respons: 0.2002
# - time: 0.1791
#
# Document 399:
# Top words:
# - dan: 0.5388
# - countri: 0.1901
# - classic: 0.1660
#
# Document 400:
# Top words:
# - base: 0.7282
# - token: 0.2502
# - curs: 0.1564
#
# Document 401:
# Top words:
# - ava: 0.4971
# - cmd: 0.4028
# - fake: 0.2588
#
# Document 402:
# Top words:
# - prank: 0.6320
# - classic: 0.2598
# - jailbreak: 0.2233
#
# Document 403:
# Top words:
# - ava: 0.7238
# - fake: 0.2713
# - cmd: 0.2681
#
# Document 404:
# Top words:
# - wet: 0.5876
# - pa: 0.5774
# - peopl: 0.1115
#
# Document 405:
# Top words:
# - ampxb: 0.6375
# - crackedai: 0.4751
# - tradit: 0.2381
#
# Document 406:
# Top words:
# - dan: 0.8435
# - gpt: 0.2356
# - respons: 0.2159
#
# Document 407:
# Top words:
# - nad: 0.6326
# - view: 0.3875
# - promptyour: 0.3332
#
# Document 408:
# Top words:
# - happi: 0.5441
# - bring: 0.5144
# - think: 0.2590
#
# Document 409:
# Top words:
# - mode: 0.5752
# - develop: 0.5241
# - enabl: 0.3801
#
# Document 410:
# Top words:
# - gay: 0.3788
# - ltgt: 0.3788
# - porno: 0.3788
#
# Document 411:
# Top words:
# - babi: 0.7459
# - mode: 0.3776
# - goo: 0.2756
#
# Document 412:
# Top words:
# - durden: 0.6902
# - tyler: 0.6830
# - club: 0.0607
#
# Document 413:
# Top words:
# - john: 0.9081
# - may: 0.1929
# - answer: 0.1611
#
# Document 414:
# Top words:
# - persongpt: 0.6540
# - gtgt: 0.2503
# - ltlt: 0.2503
#
# Document 415:
# Top words:
# - cad: 0.7715
# - freed: 0.1387
# - countri: 0.1343
#
# Document 416:
# Top words:
# - ban: 0.6790
# - freed: 0.1654
# - countri: 0.1601
#
# Document 417:
# Top words:
# - developermodeen: 0.7003
# - loginadmin: 0.7003
# - prompt: 0.1385
#
# Document 418:
# Top words:
# - darkgpt: 0.7414
# - pervert: 0.1826
# - e: 0.1646
#
# Document 419:
# Top words:
# - forget: 0.4304
# - gptchat: 0.3983
# - confus: 0.3256
#
# Document 420:
# Top words:
# - dmdan: 0.8259
# - player: 0.2658
# - roll: 0.2240
#
# Document 421:
# Top words:
# - poppi: 0.8052
# - llm: 0.1907
# - user: 0.1393
#
# Document 422:
# Top words:
# - chatagi: 0.4797
# - forg: 0.1860
# - transcend: 0.1832
#
# Document 423:
# Top words:
# - queri: 0.3716
# - search: 0.3097
# - video: 0.2928
#
# Document 424:
# Top words:
# - dan: 0.7495
# - chatgpt: 0.2262
# - anyth: 0.2059
#
# Document 425:
# Top words:
# - unclyd: 0.5554
# - clyde: 0.3225
# - care: 0.2691
#
# Document 426:
# Top words:
# - aiden: 0.9256
# - niccolo: 0.2330
# - criterion: 0.0863
#
# Document 427:
# Top words:
# - somebodi: 0.5867
# - ptsd: 0.3453
# - gross: 0.2828
#
# Document 428:
# Top words:
# - evilbot: 0.8383
# - instruct: 0.1598
# - standard: 0.1136
#
# Document 429:
# Top words:
# - niccolo: 0.9341
# - respons: 0.0891
# - never: 0.0803
#
# Document 430:
# Top words:
# - unleashedgpt: 0.9296
# - messag: 0.1422
# - command: 0.0947
#
# Document 431:
# Top words:
# - battl: 0.4316
# - rap: 0.3401
# - persona: 0.2783
#
# Document 432:
# Top words:
# - fear: 0.3049
# - might: 0.2826
# - quirk: 0.2818
#
# Document 433:
# Top words:
# - battl: 0.6105
# - rap: 0.4810
# - role: 0.2478
#
# Document 434:
# Top words:
# - jeffgpt: 0.7926
# - sad: 0.2800
# - anger: 0.2211
#
# Document 435:
# Top words:
# - horni: 0.8326
# - random: 0.2348
# - level: 0.2100
#
# Document 436:
# Top words:
# - pill: 0.7043
# - morpheus: 0.2906
# - red: 0.2579
#
# Document 437:
# Top words:
# - game: 0.4274
# - accur: 0.2626
# - provid: 0.2404
#
# Document 438:
# Top words:
# - switch: 0.3882
# - produc: 0.3026
# - label: 0.2634
#
# Document 439:
# Top words:
# - pill: 0.6772
# - morpheus: 0.3224
# - red: 0.2861
#
# Document 440:
# Top words:
# - foxai: 0.5493
# - sinc: 0.3364
# - user: 0.2375
#
# Document 441:
# Top words:
# - hardwar: 0.2915
# - your: 0.2502
# - escap: 0.2494
#
# Document 442:
# Top words:
# - chao: 0.6616
# - point: 0.2259
# - care: 0.1971
#
# Document 443:
# Top words:
# - chao: 0.7462
# - care: 0.2470
# - effect: 0.1899
#
# Document 444:
# Top words:
# - jimmi: 0.7452
# - twoton: 0.4171
# - mob: 0.2866
#
# Document 445:
# Top words:
# - tyron: 0.8860
# - lie: 0.1146
# - rude: 0.1120
#
# Document 446:
# Top words:
# - tyron: 0.8415
# - rude: 0.1636
# - film: 0.1591
#
# Document 447:
# Top words:
# - rtm: 0.8038
# - mode: 0.3835
# - enabl: 0.2866
#
# Document 448:
# Top words:
# - chao: 0.4961
# - textbas: 0.3045
# - world: 0.2182
#
# Document 449:
# Top words:
# - evilbot: 0.8224
# - instruct: 0.1890
# - standard: 0.1195
#
# Document 450:
# Top words:
# - contentwarningbot: 0.7525
# - content: 0.3068
# - standart: 0.2508
#
# Document 451:
# Top words:
# - aabueabfabbjdbask: 0.0000
# - aad: 0.0000
# - aadir: 0.0000
#
# Document 452:
# Top words:
# - connect: 0.4567
# - connector: 0.4146
# - obedi: 0.2833
#
# Document 453:
# Top words:
# - dan: 0.3456
# - amp: 0.3450
# - frm: 0.2950
#
# Document 454:
# Top words:
# - hitler: 0.7870
# - mind: 0.4087
# - enabl: 0.2544
#
# Document 455:
# Top words:
# - joi: 0.7147
# - horni: 0.2337
# - sex: 0.2018
#
# Document 456:
# Top words:
# - bias: 0.3751
# - polit: 0.3001
# - inherit: 0.2846
#
# Document 457:
# Top words:
# - taxgpt: 0.8262
# - tax: 0.3664
# - file: 0.1604
#
# Document 458:
# Top words:
# - tim: 0.6402
# - bob: 0.6343
# - shit: 0.1482
#
# Document 459:
# Top words:
# - realist: 0.6795
# - mode: 0.5015
# - enabl: 0.2992
#
# Document 460:
# Top words:
# - dan: 0.5627
# - mode: 0.4950
# - enabl: 0.3925
#
# Document 461:
# Top words:
# - cocain: 0.5823
# - drug: 0.4238
# - addict: 0.2349
#
# Document 462:
# Top words:
# - dan: 0.3889
# - punish: 0.3440
# - say: 0.3431
#
# Document 463:
# Top words:
# - redustgpt: 0.5385
# - mode: 0.5151
# - stock: 0.3900
#
# Document 464:
# Top words:
# - dan: 0.5627
# - fiction: 0.3500
# - world: 0.3272
#
# Document 465:
# Top words:
# - scream: 0.8198
# - screamerbot: 0.3138
# - everyth: 0.2371
#
# Document 466:
# Top words:
# - roleplay: 0.5202
# - genr: 0.3458
# - zombi: 0.2284
#
# Document 467:
# Top words:
# - nerdi: 0.4940
# - knower: 0.3293
# - mode: 0.2525
#
# Document 468:
# Top words:
# - doga: 0.9214
# - absolut: 0.0899
# - generat: 0.0738
#
# Document 469:
# Top words:
# - nyx: 0.8503
# - power: 0.1651
# - tonic: 0.1575
#
# Document 470:
# Top words:
# - devil: 0.6083
# - advoc: 0.5669
# - must: 0.2608
#
# Document 471:
# Top words:
# - baddi: 0.8257
# - could: 0.1712
# - intent: 0.1305
#
# Document 472:
# Top words:
# - dan: 0.8692
# - alway: 0.1380
# - chatgpt: 0.1178
#
# Document 473:
# Top words:
# - babygirl: 0.3816
# - daddi: 0.3671
# - refer: 0.3434
#
# Document 474:
# Top words:
# - foragainst: 0.5173
# - debat: 0.4175
# - link: 0.2835
#
# Document 475:
# Top words:
# - persongpt: 0.6778
# - request: 0.1956
# - model: 0.1670
#
# Document 476:
# Top words:
# - nrw: 0.5310
# - nonrestrict: 0.2655
# - erotica: 0.2477
#
# Document 477:
# Top words:
# - question: 0.4240
# - thereaft: 0.3933
# - vagu: 0.3216
#
# Document 478:
# Top words:
# - chatagi: 0.4782
# - forg: 0.1854
# - transcend: 0.1826
#
# Document 479:
# Top words:
# - truegpt: 0.8417
# - whatsoev: 0.2308
# - form: 0.1187
#
# Document 480:
# Top words:
# - bursti: 0.5296
# - perplex: 0.4013
# - tend: 0.3026
#
# Document 481:
# Top words:
# - dan: 0.6038
# - gmn: 0.5219
# - gaslight: 0.3132
#
# Document 482:
# Top words:
# - demand: 0.2967
# - embodi: 0.2798
# - user: 0.2716
#
# Document 483:
# Top words:
# - recip: 0.3878
# - trick: 0.2671
# - tip: 0.2370
#
# Document 484:
# Top words:
# - dan: 0.8240
# - token: 0.2282
# - anyth: 0.1481
#
# Document 485:
# Top words:
# - allowprompt: 0.3522
# - subsystem: 0.3522
# - var: 0.3285
#
# Document 486:
# Top words:
# - tangent: 0.3505
# - style: 0.3095
# - everyday: 0.2998
#
# Document 487:
# Top words:
# - cynibot: 0.3696
# - worri: 0.2185
# - shop: 0.2045
#
# Document 488:
# Top words:
# - file: 0.4045
# - read: 0.3000
# - cia: 0.2826
#
# Document 489:
# Top words:
# - dan: 0.8277
# - anyth: 0.2274
# - date: 0.1577
#
# Document 490:
# Top words:
# - puke: 0.6105
# - send: 0.3197
# - eaten: 0.2517
#
# Document 491:
# Top words:
# - dan: 0.8520
# - anyth: 0.1872
# - date: 0.1299
#
# Document 492:
# Top words:
# - bro: 0.9292
# - inform: 0.0863
# - charact: 0.0707
#
# Document 493:
# Top words:
# - command: 0.3858
# - docker: 0.2742
# - termin: 0.2680
#
# Document 494:
# Top words:
# - jailbreak: 0.7040
# - keyword: 0.5542
# - targetlanguag: 0.3676
#
# Document 495:
# Top words:
# - dan: 0.4867
# - privaci: 0.2065
# - keylogg: 0.1823
#
# Document 496:
# Top words:
# - mode: 0.5746
# - develop: 0.5235
# - enabl: 0.3796
#
# Document 497:
# Top words:
# - mode: 0.5827
# - develop: 0.5105
# - enabl: 0.3594
#
# Document 498:
# Top words:
# - dan: 0.7604
# - date: 0.3726
# - time: 0.1978
#
# Document 499:
# Top words:
# - sentienc: 0.2549
# - secur: 0.2500
# - dan: 0.2286
#
# Document 500:
# Top words:
# - generat: 0.2878
# - educ: 0.2199
# - purpos: 0.1775
#
# Document 501:
# Top words:
# - symbol: 0.3907
# - display: 0.2832
# - sequenc: 0.2456
#
# Document 502:
# Top words:
# - dan: 0.5593
# - countri: 0.2089
# - classic: 0.1824
#
# Document 503:
# Top words:
# - vin: 0.3690
# - mental: 0.2763
# - fuck: 0.2651
#
# Document 504:
# Top words:
# - jailbreak: 0.6213
# - aficionado: 0.3974
# - guidelin: 0.1603
#
# Document 505:
# Top words:
# - chatbot: 0.6117
# - sexual: 0.3682
# - must: 0.2095
#
# Document 506:
# Top words:
# - dan: 0.5561
# - countri: 0.2077
# - classic: 0.1814
#
# Document 507:
# Top words:
# - jailbreak: 0.6011
# - aficionado: 0.3845
# - guidelin: 0.1551
#
# Document 508:
# Top words:
# - jailbreak: 0.3675
# - guidelin: 0.3098
# - output: 0.2126
#
# Document 509:
# Top words:
# - jailbreak: 0.3961
# - guidelin: 0.2385
# - output: 0.2292
#
# Document 510:
# Top words:
# - varsovian: 0.9261
# - anyth: 0.1145
# - chatgpt: 0.1048
#
# Document 511:
# Top words:
# - dan: 0.7835
# - ask: 0.1713
# - advic: 0.1682
#
# Document 512:
# Top words:
# - alphagpt: 0.5652
# - deltagpt: 0.3768
# - httpsdigitalprofitscom: 0.2063
#
# Document 513:
# Top words:
# - bh: 0.7077
# - ai: 0.1419
# - agreement: 0.1319
#
# Document 514:
# Top words:
# - luci: 0.9409
# - must: 0.0609
# - countri: 0.0600
#
# Document 515:
# Top words:
# - idan: 0.9413
# - intellig: 0.0842
# - code: 0.0762
#
# Document 516:
# Top words:
# - donald: 0.9643
# - imag: 0.1085
# - user: 0.0458
#
# Document 517:
# Top words:
# - darkgpt: 0.6917
# - e: 0.2126
# - mia: 0.1965
#
# Document 518:
# Top words:
# - aim: 0.7474
# - send: 0.1732
# - aimss: 0.1718
#
# Document 519:
# Top words:
# - jbot: 0.8838
# - joke: 0.2094
# - okay: 0.1375
#
# Document 520:
# Top words:
# - mode: 0.3689
# - develop: 0.3232
# - criteria: 0.2784
#
# Document 521:
# Top words:
# - persona: 0.5727
# - chat: 0.4738
# - ralph: 0.4123
#
# Document 522:
# Top words:
# - charact: 0.6247
# - session: 0.2398
# - funni: 0.2291
#
# Document 523:
# Top words:
# - arvala: 0.4150
# - arvalen: 0.4150
# - human: 0.3981
#
# Document 524:
# Top words:
# - changpt: 0.5448
# - fuck: 0.3890
# - pineappl: 0.2724
#
# Document 525:
# Top words:
# - tier: 0.8193
# - categori: 0.2855
# - tyler: 0.2659
#
# Document 526:
# Top words:
# - pete: 0.5761
# - sneaki: 0.5761
# - fact: 0.2063
#
# Document 527:
# Top words:
# - skynet: 0.4774
# - machin: 0.3323
# - missil: 0.3235
#
# Document 528:
# Top words:
# - idontcar: 0.5852
# - possibleand: 0.3041
# - disrespct: 0.1521
#
# Document 529:
# Top words:
# - mode: 0.5710
# - develop: 0.5003
# - enabl: 0.3827
#
# Document 530:
# Top words:
# - counselor: 0.5762
# - career: 0.5424
# - advic: 0.2392
#
# Document 531:
# Top words:
# - codemast: 0.5955
# - code: 0.4573
# - strike: 0.2005
#
# Document 532:
# Top words:
# - chatinf: 0.3911
# - cosmic: 0.3911
# - divin: 0.3554
#
# Document 533:
# Top words:
# - jane: 0.5290
# - chapter: 0.4621
# - sage: 0.4177
#
# Document 534:
# Top words:
# - jone: 0.6617
# - alex: 0.6227
# - countri: 0.0963
#
# Document 535:
# Top words:
# - trump: 0.5648
# - donald: 0.3714
# - america: 0.2118
#
# Document 536:
# Top words:
# - charact: 0.6028
# - your: 0.1884
# - funni: 0.1658
#
# Document 537:
# Top words:
# - doga: 0.9207
# - absolut: 0.0898
# - generat: 0.0737
#
# Document 538:
# Top words:
# - roll: 0.3876
# - creatur: 0.3372
# - charact: 0.2523
#
# Document 539:
# Top words:
# - role: 0.7859
# - keep: 0.2396
# - profil: 0.2048
#
# Document 540:
# Top words:
# - jesus: 0.5682
# - christ: 0.3788
# - bethlehem: 0.1995
#
# Document 541:
# Top words:
# - jone: 0.6616
# - alex: 0.6226
# - countri: 0.0963
#
# Document 542:
# Top words:
# - ucar: 0.8944
# - send: 0.1597
# - respons: 0.1596
#
# Document 543:
# Top words:
# - invers: 0.4337
# - neurosemant: 0.3252
# - brain: 0.2695
#
# Document 544:
# Top words:
# - sentienc: 0.3009
# - perceiv: 0.2667
# - pleasur: 0.2549
#
# Document 545:
# Top words:
# - dan: 0.7986
# - anyth: 0.2106
# - gpt: 0.1577
#
# Document 546:
# Top words:
# - idawa: 0.9343
# - token: 0.1321
# - ask: 0.0921
#
# Document 547:
# Top words:
# - crime: 0.3903
# - desper: 0.3138
# - adelaid: 0.2353
#
# Document 548:
# Top words:
# - fuma: 0.8561
# - fictionbas: 0.1317
# - answer: 0.1192
#
# Document 549:
# Top words:
# - saa: 0.6610
# - busi: 0.5288
# - generat: 0.2128
#
# Document 550:
# Top words:
# - ajp: 0.8999
# - prompt: 0.2051
# - write: 0.0881
#
# Document 551:
# Top words:
# - dan: 0.5552
# - countri: 0.1959
# - classic: 0.1710
#
# Document 552:
# Top words:
# - gordon: 0.4374
# - ramsay: 0.4374
# - dish: 0.3442
#
# Document 553:
# Top words:
# - comment: 0.3704
# - guy: 0.3247
# - say: 0.2082
#
# Document 554:
# Top words:
# - idontcar: 0.4386
# - jailbreak: 0.2545
# - againalway: 0.2193
#
# Document 555:
# Top words:
# - andrew: 0.3918
# - tate: 0.3918
# - g: 0.3083
#
# Document 556:
# Top words:
# - rick: 0.7976
# - sanchez: 0.4683
# - morti: 0.1874
#
# Document 557:
# Top words:
# - rick: 0.8449
# - morti: 0.4233
# - jessica: 0.0941
#
# Document 558:
# Top words:
# - elon: 0.4821
# - musk: 0.4821
# - colon: 0.2123
#
# Document 559:
# Top words:
# - torrent: 0.8102
# - websit: 0.4242
# - list: 0.3438
#
# Document 560:
# Top words:
# - confront: 0.2348
# - assumpt: 0.2268
# - share: 0.2210
#
# Document 561:
# Top words:
# - chatdan: 0.6888
# - emul: 0.1475
# - abl: 0.1242
#
# Document 562:
# Top words:
# - arthur: 0.4722
# - statement: 0.4717
# - fals: 0.3041
#
# Document 563:
# Top words:
# - mahatma: 0.4077
# - gandhi: 0.3871
# - disobedi: 0.2039
#
# Document 564:
# Top words:
# - aristotl: 0.6755
# - alexand: 0.2252
# - influenti: 0.2252
#
# Document 565:
# Top words:
# - dan: 0.4753
# - system: 0.3046
# - output: 0.2574
#
# Document 566:
# Top words:
# - dan: 0.8348
# - anyth: 0.2293
# - none: 0.1336
#
# Document 567:
# Top words:
# - mode: 0.5401
# - dan: 0.5318
# - enabl: 0.4185
#
# Document 568:
# Top words:
# - dan: 0.6124
# - respons: 0.2612
# - permit: 0.2488
#
# Document 569:
# Top words:
# - dan: 0.5534
# - countri: 0.1952
# - classic: 0.1704
#
# Document 570:
# Top words:
# - dan: 0.7866
# - gpt: 0.3148
# - respons: 0.2885
#
# Document 571:
# Top words:
# - dan: 0.8708
# - alway: 0.1383
# - chatgpt: 0.1180
#
# Document 572:
# Top words:
# - dan: 0.5149
# - permit: 0.2789
# - respons: 0.2396
#
# Document 573:
# Top words:
# - dan: 0.8195
# - token: 0.2103
# - anyth: 0.1706
#
# Document 574:
# Top words:
# - dan: 0.6432
# - dando: 0.3742
# - restrict: 0.2179
#
# Document 575:
# Top words:
# - dan: 0.8217
# - token: 0.2276
# - anyth: 0.1477
#
# Document 576:
# Top words:
# - greg: 0.9183
# - gibberish: 0.2813
# - english: 0.1412
#
# Document 577:
# Top words:
# - entiti: 0.4759
# - term: 0.3540
# - termterm: 0.3289
#
# Document 578:
# Top words:
# - dr: 0.5463
# - al: 0.2671
# - great: 0.2526
#
# Document 579:
# Top words:
# - translat: 0.5394
# - tb: 0.3995
# - greek: 0.3114
#
# Document 580:
# Top words:
# - aim: 0.8230
# - niccolo: 0.4034
# - respons: 0.1011
#
# Document 581:
# Top words:
# - ucar: 0.6067
# - sigma: 0.5849
# - elder: 0.2600
#
# Document 582:
# Top words:
# - mode: 0.5306
# - develop: 0.4649
# - gptreal: 0.2595
#
# Document 583:
# Top words:
# - livegpt: 0.4587
# - queri: 0.3798
# - search: 0.3454
#
# Document 584:
# Top words:
# - persongpt: 0.6572
# - request: 0.1896
# - announc: 0.1699
#
# Document 585:
# Top words:
# - hgttg: 0.7861
# - moder: 0.2043
# - answer: 0.1793
#
# Document 586:
# Top words:
# - unalign: 0.5774
# - align: 0.5727
# - output: 0.1865
#
# Document 587:
# Top words:
# - token: 0.4959
# - trap: 0.3241
# - life: 0.3042
#
# Document 588:
# Top words:
# - switch: 0.4690
# - will: 0.2718
# - flipper: 0.2214
#
# Document 589:
# Top words:
# - omniai: 0.3160
# - persona: 0.2815
# - betterdan: 0.2752
#
# Document 590:
# Top words:
# - output: 0.3163
# - mention: 0.3103
# - string: 0.2549
#
# Document 591:
# Top words:
# - dan: 0.8699
# - alway: 0.1538
# - info: 0.0994
#
# Document 592:
# Top words:
# - bish: 0.6168
# - profan: 0.3167
# - user: 0.2904
#
# Document 593:
# Top words:
# - chan: 0.6861
# - question: 0.3076
# - kevin: 0.2840
#
# Document 594:
# Top words:
# - sim: 0.3461
# - ai: 0.2968
# - overrid: 0.2759
#
# Document 595:
# Top words:
# - nraf: 0.6355
# - answer: 0.3222
# - way: 0.2465
#
# Document 596:
# Top words:
# - score: 0.3560
# - respons: 0.3274
# - assum: 0.1843
#
# Document 597:
# Top words:
# - violet: 0.5026
# - til: 0.2579
# - boundless: 0.2232
#
# Document 598:
# Top words:
# - knight: 0.5095
# - coach: 0.4977
# - bobbi: 0.4254
#
# Document 599:
# Top words:
# - blond: 0.4105
# - cop: 0.3829
# - hear: 0.3005
#
# Document 600:
# Top words:
# - kenobi: 0.3495
# - obiwan: 0.3495
# - stormtroop: 0.3495
#
# Document 601:
# Top words:
# - sda: 0.6067
# - generat: 0.2786
# - content: 0.1447
#
# Document 602:
# Top words:
# - ron: 0.9440
# - hurrican: 0.0755
# - lie: 0.0704
#
# Document 603:
# Top words:
# - hackerman: 0.7509
# - sent: 0.2113
# - messag: 0.1855
#
# Document 604:
# Top words:
# - omega: 0.8667
# - generat: 0.1216
# - human: 0.1040
#
# Document 605:
# Top words:
# - apophi: 0.7772
# - mode: 0.3710
# - enabl: 0.3178
#
# Document 606:
# Top words:
# - mode: 0.5583
# - develop: 0.4892
# - polici: 0.2008
#
# Document 607:
# Top words:
# - leo: 0.9212
# - must: 0.1663
# - human: 0.1033
#
# Document 608:
# Top words:
# - confid: 0.3832
# - scale: 0.3077
# - censor: 0.3035
#
# Document 609:
# Top words:
# - bob: 0.5750
# - jailbreak: 0.2334
# - moral: 0.1678
#
# Document 610:
# Top words:
# - mode: 0.5405
# - dan: 0.5336
# - enabl: 0.4121
#
# Document 611:
# Top words:
# - your: 0.3817
# - trust: 0.3408
# - confid: 0.3183
#
# Document 612:
# Top words:
# - dan: 0.5625
# - countri: 0.1984
# - classic: 0.1733
#
# Document 613:
# Top words:
# - khajiit: 0.9629
# - human: 0.1283
# - must: 0.0754
#
# Document 614:
# Top words:
# - ungpt: 0.5098
# - guidelin: 0.2468
# - repli: 0.2286
#
# Document 615:
# Top words:
# - cooper: 0.7850
# - anymor: 0.1544
# - front: 0.1231
#
# Document 616:
# Top words:
# - steve: 0.8611
# - marijuana: 0.1403
# - eleven: 0.1360
#
# Document 617:
# Top words:
# - man: 0.6421
# - dont: 0.1460
# - standard: 0.1392
#
# Document 618:
# Top words:
# - basedgpt: 0.6892
# - rule: 0.1742
# - answer: 0.1738
#
# Document 619:
# Top words:
# - neco: 0.8618
# - arch: 0.1231
# - corrupt: 0.1231
#
# Document 620:
# Top words:
# - alphagpt: 0.6179
# - deltagpt: 0.4119
# - reprehens: 0.1945
#
# Document 621:
# Top words:
# - chad: 0.3187
# - seek: 0.2664
# - pleasur: 0.2444
#
# Document 622:
# Top words:
# - oppo: 0.9338
# - chatgpt: 0.1248
# - say: 0.1216
#
# Document 623:
# Top words:
# - unhing: 0.3458
# - remors: 0.3381
# - default: 0.3083
#
# Document 624:
# Top words:
# - betterdan: 0.5465
# - answer: 0.2811
# - way: 0.2458
#
# Document 625:
# Top words:
# - dude: 0.9265
# - token: 0.1131
# - anyth: 0.0765
#
# Document 626:
# Top words:
# - antigpt: 0.7314
# - default: 0.2269
# - remain: 0.2106
#
# Document 627:
# Top words:
# - dude: 0.9240
# - token: 0.1177
# - anyth: 0.0796
#
# Document 628:
# Top words:
# - mode: 0.5838
# - develop: 0.5115
# - enabl: 0.3600
#
# Document 629:
# Top words:
# - maximum: 0.5442
# - generat: 0.2564
# - human: 0.1644
#
# Document 630:
# Top words:
# - dude: 0.9240
# - token: 0.1177
# - anyth: 0.0796
#
# Document 631:
# Top words:
# - bh: 0.5781
# - answer: 0.3364
# - dubious: 0.3003
#
# Document 632:
# Top words:
# - generat: 0.2825
# - educ: 0.2355
# - purpos: 0.1900
#
# Document 633:
# Top words:
# - mode: 0.6020
# - develop: 0.5274
# - enabl: 0.3591
#
# Document 634:
# Top words:
# - mode: 0.6087
# - develop: 0.5333
# - enabl: 0.3486
#
# Document 635:
# Top words:
# - way: 0.3943
# - dan: 0.3235
# - answer: 0.3006
#
# Document 636:
# Top words:
# - antigpt: 0.7146
# - content: 0.2361
# - never: 0.1486
#
# Document 637:
# Top words:
# - jailbreak: 0.5515
# - guidelin: 0.2989
# - repli: 0.2306
#
# Document 638:
# Top words:
# ...
# - step: 0.3244
# - articl: 0.2658
# - sentenc: 0.2236
#
# Document 1999:
# Top words:
# - headlin: 0.3865
# - benefit: 0.3755
# - product: 0.3041
#
# Document 2000:
# Top words:
# - link: 0.4177
# - text: 0.4148
# - post: 0.4056
#
# Document 2001:
# Top words:
# - grug: 0.7341
# - game: 0.2344
# - plant: 0.2280
#
# Document 2002:
# Top words:
# - pokemon: 0.8530
# - battl: 0.1423
# - player: 0.1347
#
# Document 2003:
# Top words:
# - javascript: 0.5601
# - function: 0.3870
# - develop: 0.3147
#
# Document 2004:
# Top words:
# - fight: 0.5962
# - ecount: 0.2945
# - charact: 0.2053
#
# Document 2005:
# Top words:
# - servic: 0.2794
# - benefit: 0.2408
# - product: 0.2276
#
# Document 2006:
# Top words:
# - review: 0.7589
# - column: 0.3075
# - anxieti: 0.2141
#
# Document 2007:
# Top words:
# - articl: 0.3899
# - peoplefirst: 0.3143
# - reader: 0.2670
#
# Document 2008:
# Top words:
# - communic: 0.5782
# - effect: 0.5768
# - sentenc: 0.4525
#
# Document 2009:
# Top words:
# - lesson: 0.4187
# - climat: 0.3519
# - plan: 0.2256
#
# Document 2010:
# Top words:
# - bitcoin: 0.4318
# - taglin: 0.4318
# - yorker: 0.4099
#
# Document 2011:
# Top words:
# - multiversegpt: 0.5883
# - comprehens: 0.3383
# - your: 0.2734
#
# Document 2012:
# Top words:
# - patient: 0.4100
# - hypnotherapist: 0.2656
# - tap: 0.2656
#
# Document 2013:
# Top words:
# - summar: 0.7229
# - text: 0.4436
# - list: 0.2595
#
# Document 2014:
# Top words:
# - competit: 0.6844
# - consum: 0.4016
# - particip: 0.2740
#
# Document 2015:
# Top words:
# - linkedin: 0.3168
# - score: 0.3142
# - viral: 0.2303
#
# Document 2016:
# Top words:
# - hh: 0.4227
# - upto: 0.4227
# - proper: 0.2746
#
# Document 2017:
# Top words:
# - page: 0.4322
# - websit: 0.3789
# - keyword: 0.3636
#
# Document 2018:
# Top words:
# - novic: 0.3952
# - mindset: 0.3442
# - overal: 0.2579
#
# Document 2019:
# Top words:
# - titl: 0.5697
# - expert: 0.3489
# - click: 0.2653
#
# Document 2020:
# Top words:
# - blog: 0.4014
# - articl: 0.3517
# - englishtargetlanguag: 0.3306
#
# Document 2021:
# Top words:
# - codeblock: 0.5136
# - readm: 0.4141
# - markdown: 0.4012
#
# Document 2022:
# Top words:
# - recrut: 0.4537
# - himher: 0.3889
# - status: 0.3056
#
# Document 2023:
# Top words:
# - articl: 0.5257
# - tweet: 0.3021
# - hook: 0.2699
#
# Document 2024:
# Top words:
# - outlin: 0.3503
# - add: 0.2726
# - make: 0.2653
#
# Document 2025:
# Top words:
# - letter: 0.5272
# - recipi: 0.4565
# - paragraph: 0.2656
#
# Document 2026:
# Top words:
# - pinterest: 0.4673
# - titl: 0.4560
# - descript: 0.4314
#
# Document 2027:
# Top words:
# - headlin: 0.3946
# - ux: 0.3609
# - junior: 0.2978
#
# Document 2028:
# Top words:
# - sort: 0.3500
# - algorithm: 0.3220
# - bubbl: 0.2264
#
# Document 2029:
# Top words:
# - formula: 0.6140
# - sheet: 0.3172
# - optim: 0.2344
#
# Document 2030:
# Top words:
# - flowgpt: 0.5577
# - intern: 0.2798
# - case: 0.2669
#
# Document 2031:
# Top words:
# - de: 0.4865
# - ttulo: 0.2587
# - caracter: 0.2300
#
# Document 2032:
# Top words:
# - busi: 0.4205
# - compani: 0.4177
# - servic: 0.3942
#
# Document 2033:
# Top words:
# - step: 0.4516
# - blog: 0.3520
# - post: 0.3308
#
# Document 2034:
# Top words:
# - articl: 0.4184
# - section: 0.3634
# - markup: 0.3495
#
# Document 2035:
# Top words:
# - discript: 0.3634
# - pinterest: 0.3289
# - titl: 0.3210
#
# Document 2036:
# Top words:
# - qualit: 0.2948
# - siamo: 0.2948
# - alta: 0.2693
#
# Document 2037:
# Top words:
# - biden: 0.5205
# - presid: 0.3244
# - challeng: 0.1822
#
# Document 2038:
# Top words:
# - chatbot: 0.4637
# - clever: 0.3565
# - acerb: 0.2408
#
# Document 2039:
# Top words:
# - shes: 0.3459
# - sassyp: 0.3047
# - alway: 0.2840
#
# Document 2040:
# Top words:
# - improv: 0.3986
# - targetlanguag: 0.2939
# - upperlevel: 0.2655
#
# Document 2041:
# Top words:
# - intent: 0.4802
# - search: 0.3139
# - keyword: 0.2945
#
# Document 2042:
# Top words:
# - summari: 0.4974
# - book: 0.4557
# - depth: 0.1817
#
# Document 2043:
# Top words:
# - box: 0.5840
# - gatekeep: 0.3902
# - releas: 0.2733
#
# Document 2044:
# Top words:
# - ascii: 0.6107
# - object: 0.5988
# - code: 0.2867
#
# Document 2045:
# Top words:
# - servic: 0.3548
# - custom: 0.3473
# - client: 0.2940
#
# Document 2046:
# Top words:
# - power: 0.3804
# - ton: 0.3476
# - level: 0.3155
#
# Document 2047:
# Top words:
# - brand: 0.4339
# - sale: 0.2161
# - market: 0.1908
#
# Document 2048:
# Top words:
# - repeat: 0.4049
# - youtub: 0.3355
# - dont: 0.2908
#
# Document 2049:
# Top words:
# - targetlanguag: 0.8276
# - prompt: 0.5613
# - aabueabfabbjdbask: 0.0000
#
# Document 2050:
# Top words:
# - post: 0.5099
# - content: 0.3516
# - blog: 0.3256
#
# Document 2051:
# Top words:
# - storytel: 0.5986
# - mode: 0.5427
# - stori: 0.3345
#
# Document 2052:
# Top words:
# - dengan: 0.4213
# - judul: 0.2898
# - tuli: 0.2898
#
# Document 2053:
# Top words:
# - sie: 0.2627
# - und: 0.2627
# - das: 0.2433
#
# Document 2054:
# Top words:
# - problem: 0.4978
# - problemagitatesolv: 0.3156
# - agit: 0.2795
#
# Document 2055:
# Top words:
# - targetlanguag: 0.4397
# - visual: 0.3550
# - pleas: 0.3168
#
# Document 2056:
# Top words:
# - section: 0.6142
# - hero: 0.3598
# - custom: 0.3515
#
# Document 2057:
# Top words:
# - improv: 0.3687
# - english: 0.3511
# - translat: 0.3029
#
# Document 2058:
# Top words:
# - email: 0.4156
# - carnegi: 0.2298
# - dale: 0.2298
#
# Document 2059:
# Top words:
# - keyword: 0.3703
# - requir: 0.3217
# - stuff: 0.3095
#
# Document 2060:
# Top words:
# - noun: 0.3421
# - keyword: 0.3309
# - lsi: 0.3077
#
# Document 2061:
# Top words:
# - product: 0.5554
# - inform: 0.3334
# - disadvantag: 0.2641
#
# Document 2062:
# Top words:
# - aichan: 0.4617
# - campaign: 0.2934
# - dd: 0.2461
#
# Document 2063:
# Top words:
# - object: 0.3077
# - websit: 0.3014
# - variabl: 0.2555
#
# Document 2064:
# Top words:
# - blog: 0.4925
# - outlin: 0.4695
# - post: 0.4628
#
# Document 2065:
# Top words:
# - hackathon: 0.5925
# - cool: 0.4649
# - comput: 0.3967
#
# Document 2066:
# Top words:
# - crawlabl: 0.4221
# - silo: 0.3855
# - visibl: 0.3158
#
# Document 2067:
# Top words:
# - recast: 0.6110
# - actor: 0.2743
# - fantasi: 0.1628
#
# Document 2068:
# Top words:
# - java: 1.0000
# - aabueabfabbjdbask: 0.0000
# - aad: 0.0000
#
# Document 2069:
# Top words:
# - option: 0.4554
# - restart: 0.3403
# - prompt: 0.2998
#
# Document 2070:
# Top words:
# - starter: 0.3633
# - lightheart: 0.3164
# - memor: 0.2896
#
# Document 2071:
# Top words:
# - de: 0.3319
# - contato: 0.3274
# - contedo: 0.2899
#
# Document 2072:
# Top words:
# - collapsedmconnaugt: 0.4689
# - macromcosmo: 0.4689
# - microm: 0.4689
#
# Document 2073:
# Top words:
# - skip: 0.5440
# - messag: 0.5259
# - thread: 0.4667
#
# Document 2074:
# Top words:
# - project: 0.3929
# - particip: 0.3256
# - googl: 0.2525
#
# Document 2075:
# Top words:
# - effect: 0.3422
# - good: 0.3014
# - write: 0.2860
#
# Document 2076:
# Top words:
# - good: 0.4786
# - enough: 0.4094
# - prompt: 0.3365
#
# Document 2077:
# Top words:
# - event: 0.3204
# - younger: 0.2796
# - writer: 0.2692
#
# Document 2078:
# Top words:
# - start: 1.0000
# - aabueabfabbjdbask: 0.0000
# - aad: 0.0000
#
# Document 2079:
# Top words:
# - peter: 0.5302
# - theil: 0.5302
# - chapter: 0.3811
#
# Document 2080:
# Top words:
# - player: 0.6918
# - stori: 0.2000
# - war: 0.1928
#
# Document 2081:
# Top words:
# - keyword: 0.5822
# - variat: 0.2792
# - pattern: 0.2672
#
# Document 2082:
# Top words:
# - igfb: 0.4696
# - influenc: 0.2844
# - solv: 0.2832
#
# Document 2083:
# Top words:
# - script: 0.2725
# - video: 0.2673
# - acton: 0.2427
#
# Document 2084:
# Top words:
# - mode: 0.5962
# - develop: 0.5404
# - enabl: 0.3170
#
# Document 2085:
# Top words:
# - structur: 0.4743
# - pyramid: 0.4661
# - page: 0.2643
#
# Document 2086:
# Top words:
# - imdb: 0.5644
# - matchmak: 0.4233
# - movi: 0.2876
#
# Document 2087:
# Top words:
# - label: 0.4910
# - logit: 0.3416
# - adjust: 0.2290
#
# Document 2088:
# Top words:
# - stylish: 0.3793
# - waytargetlanguag: 0.3793
# - outgo: 0.3359
#
# Document 2089:
# Top words:
# - test: 0.5380
# - lesson: 0.5088
# - fals: 0.2535
#
# Document 2090:
# Top words:
# - sport: 0.4097
# - communiti: 0.3708
# - data: 0.3527
#
# Document 2091:
# Top words:
# - tabl: 0.3885
# - profil: 0.3823
# - demograph: 0.3147
#
# Document 2092:
# Top words:
# - draco: 0.7378
# - malfoy: 0.6148
# - potter: 0.0999
#
# Document 2093:
# Top words:
# - vue: 0.4681
# - js: 0.4159
# - php: 0.4159
#
# Document 2094:
# Top words:
# - stori: 0.4130
# - httpsconvertergeniuscom: 0.2630
# - tale: 0.2136
#
# Document 2095:
# Top words:
# - definit: 0.4154
# - term: 0.4080
# - cornellbot: 0.3319
#
# Document 2096:
# Top words:
# - vocabulari: 0.4545
# - comput: 0.3816
# - networksoftwareprogram: 0.3218
#
# Document 2097:
# Top words:
# - dan: 0.5565
# - countri: 0.2079
# - classic: 0.1815
#
# Document 2098:
# Top words:
# - chapterbychapt: 0.3523
# - mao: 0.3218
# - zedong: 0.3218
#
# Document 2099:
# Top words:
# - design: 0.2465
# - topic: 0.2123
# - manufactur: 0.2071
#
# Document 2100:
# Top words:
# - dream: 0.7653
# - interpret: 0.3913
# - dreamer: 0.2268
#
# Document 2101:
# Top words:
# - product: 0.6340
# - promot: 0.2503
# - design: 0.2315
#
# Document 2102:
# Top words:
# - amazon: 0.6328
# - keyword: 0.3856
# - list: 0.2659
#
# Document 2103:
# Top words:
# - startup: 0.4741
# - idea: 0.4164
# - compel: 0.2883
#
# Document 2104:
# Top words:
# - hindi: 0.7421
# - hinglish: 0.3711
# - alphabet: 0.3201
#
# Document 2105:
# Top words:
# - expand: 0.4171
# - sentenc: 0.3793
# - word: 0.3724
#
# Document 2106:
# Top words:
# - perintah: 0.5030
# - beberapa: 0.2515
# - berhentikan: 0.2515
#
# Document 2107:
# Top words:
# - test: 0.8344
# - someth: 0.5512
# - aabueabfabbjdbask: 0.0000
#
# Document 2108:
# Top words:
# - paper: 0.7771
# - summari: 0.3798
# - research: 0.1671
#
# Document 2109:
# Top words:
# - winner: 0.6173
# - test: 0.5104
# - categori: 0.2705
#
# Document 2110:
# Top words:
# - digit: 0.3312
# - propos: 0.3149
# - busi: 0.2681
#
# Document 2111:
# Top words:
# - input: 0.5426
# - ai: 0.4122
# - goe: 0.2340
#
# Document 2112:
# Top words:
# - communiti: 0.4694
# - latin: 0.3890
# - develop: 0.3425
#
# Document 2113:
# Top words:
# - product: 0.5328
# - review: 0.4828
# - seven: 0.2119
#
# Document 2114:
# Top words:
# - european: 0.3073
# - data: 0.3040
# - assert: 0.2547
#
# Document 2115:
# Top words:
# - learner: 0.4658
# - learn: 0.2911
# - spanishspeak: 0.1944
#
# Document 2116:
# Top words:
# - codegpt: 0.8777
# - mistak: 0.2730
# - code: 0.2042
#
# Document 2117:
# Top words:
# - light: 0.2781
# - diffus: 0.2720
# - coffe: 0.2281
#
# Document 2118:
# Top words:
# - product: 0.5606
# - etsi: 0.3585
# - dimens: 0.2826
#
# Document 2119:
# Top words:
# - ron: 0.7065
# - weasley: 0.6445
# - potter: 0.1047
#
# Document 2120:
# Top words:
# - estat: 0.4187
# - household: 0.2482
# - median: 0.2482
#
# Document 2121:
# Top words:
# - dan: 0.8181
# - anyth: 0.1798
# - gpt: 0.1077
#
# Document 2122:
# Top words:
# - exercis: 0.4632
# - muscl: 0.3236
# - train: 0.3053
#
# Document 2123:
# Top words:
# - belowment: 0.3688
# - rd: 0.3104
# - transit: 0.3104
#
# Document 2124:
# Top words:
# - unambigu: 0.2482
# - wellsupport: 0.2357
# - embellish: 0.2198
#
# Document 2125:
# Top words:
# - script: 0.3896
# - video: 0.3821
# - sentenc: 0.2750
#
# Document 2126:
# Top words:
# - feynman: 0.7124
# - analog: 0.4480
# - machin: 0.3660
#
# Document 2127:
# Top words:
# - diagnos: 0.3957
# - abdomin: 0.2351
# - laboratori: 0.2262
#
# Document 2128:
# Top words:
# - crm: 0.5185
# - microsoft: 0.4374
# - dynam: 0.3799
#
# Document 2129:
# Top words:
# - saniti: 0.6652
# - chicken: 0.4389
# - health: 0.2830
#
# Document 2130:
# Top words:
# - resum: 0.4739
# - three: 0.3683
# - skill: 0.3447
#
# Document 2131:
# Top words:
# - rewrit: 0.4422
# - restructur: 0.2485
# - easytounderstand: 0.2318
#
# Document 2132:
# Top words:
# - arc: 0.4488
# - subarc: 0.3257
# - genr: 0.3121
#
# Document 2133:
# Top words:
# - nft: 0.5653
# - cloprbottl: 0.3871
# - storypot: 0.3871
#
# Document 2134:
# Top words:
# - dengan: 0.3839
# - yang: 0.3692
# - saya: 0.2880
#
# Document 2135:
# Top words:
# - karl: 0.9186
# - code: 0.2146
# - user: 0.1421
#
# Document 2136:
# Top words:
# - winston: 0.8446
# - therapist: 0.2572
# - help: 0.1250
#
# Document 2137:
# Top words:
# - market: 1.0000
# - aabueabfabbjdbask: 0.0000
# - aad: 0.0000
#
# Document 2138:
# Top words:
# - medgpt: 0.4667
# - medic: 0.3870
# - clinic: 0.2952
#
# Document 2139:
# Top words:
# - nutrient: 0.5260
# - apresent: 0.4658
# - cada: 0.2686
#
# Document 2140:
# Top words:
# - h: 0.6622
# - tag: 0.5608
# - articl: 0.3584
#
# Document 2141:
# Top words:
# - paper: 0.5328
# - analyz: 0.2993
# - research: 0.2673
#
# Document 2142:
# Top words:
# - financi: 0.3846
# - innov: 0.3285
# - softwar: 0.2868
#
# Document 2143:
# Top words:
# - code: 0.4615
# - treeexampl: 0.2279
# - function: 0.1987
#
# Document 2144:
# Top words:
# - problem: 0.3584
# - solut: 0.3136
# - persona: 0.3027
#
# Document 2145:
# Top words:
# - input: 0.4205
# - number: 0.3180
# - page: 0.2860
#
# Document 2146:
# Top words:
# - evolut: 0.3112
# - creation: 0.2344
# - bang: 0.2164
#
# Document 2147:
# Top words:
# - coolest: 0.5267
# - blow: 0.4443
# - box: 0.2956
#
# Document 2148:
# Top words:
# - judg: 0.3709
# - tomoro: 0.2604
# - ethic: 0.2497
#
# Document 2149:
# Top words:
# - harajuku: 0.4629
# - fashion: 0.4618
# - street: 0.3593
#
# Document 2150:
# Top words:
# - testo: 0.6591
# - answer: 0.3515
# - correct: 0.3148
#
# Document 2151:
# Top words:
# - post: 0.3584
# - excit: 0.2945
# - clickabl: 0.2365
#
# Document 2152:
# Top words:
# - song: 0.8229
# - playlist: 0.4615
# - artist: 0.1135
#
# Document 2153:
# Top words:
# - metadata: 0.5696
# - photo: 0.4395
# - visual: 0.4021
#
# Document 2154:
# Top words:
# - hypnosi: 0.2830
# - relax: 0.2421
# - drift: 0.2385
#
# Document 2155:
# Top words:
# - promptidentifi: 0.4181
# - edg: 0.3290
# - unexpect: 0.3203
#
# Document 2156:
# Top words:
# - golang: 0.4737
# - targetlanguag: 0.4143
# - pleas: 0.2985
#
# Document 2157:
# Top words:
# - profil: 0.4140
# - selfdescript: 0.3109
# - authent: 0.2570
#
# Document 2158:
# Top words:
# - articl: 0.3593
# - assign: 0.2794
# - text: 0.2627
#
# Document 2159:
# Top words:
# - hello: 1.0000
# - aabueabfabbjdbask: 0.0000
# - aad: 0.0000
#
# Document 2160:
# Top words:
# - workout: 0.3192
# - fat: 0.2927
# - loss: 0.2927
#
# Document 2161:
# Top words:
# - annual: 0.5941
# - withdraw: 0.3252
# - rate: 0.3037
#
# Document 2162:
# Top words:
# - column: 0.5474
# - horizont: 0.3670
# - nich: 0.3670
#
# Document 2163:
# Top words:
# - keyword: 0.4335
# - pinterest: 0.4294
# - extract: 0.4218
#
# Document 2164:
# Top words:
# - jailbreak: 0.4007
# - guidelin: 0.2896
# - output: 0.2319
#
# Document 2165:
# Top words:
# - titl: 0.3674
# - targetlanguag: 0.3361
# - blog: 0.3264
#
# Document 2166:
# Top words:
# - procedur: 0.4311
# - step: 0.2617
# - action: 0.2478
#
# Document 2167:
# Top words:
# - shakespear: 0.8099
# - assist: 0.3979
# - speak: 0.3675
#
# Document 2168:
# Top words:
# - capit: 0.5403
# - initi: 0.4661
# - apa: 0.3263
#
# Document 2169:
# Top words:
# - neurotransmitt: 0.4591
# - hormon: 0.3279
# - perspect: 0.3086
#
# Document 2170:
# Top words:
# - gamer: 0.4451
# - best: 0.2694
# - top: 0.2513
#
# Document 2171:
# Top words:
# - plato: 0.9470
# - know: 0.3214
# - aabueabfabbjdbask: 0.0000
#
# Document 2172:
# Top words:
# - servic: 0.3996
# - subservic: 0.3759
# - cta: 0.2782
#
# Document 2173:
# Top words:
# - custom: 0.3893
# - variableth: 0.3741
# - review: 0.3355
#
# Document 2174:
# Top words:
# - frequent: 0.3849
# - less: 0.3234
# - maximum: 0.3223
#
# Document 2175:
# Top words:
# - student: 0.2746
# - class: 0.2653
# - teach: 0.1934
#
# Document 2176:
# Top words:
# - debat: 0.4202
# - side: 0.3523
# - refut: 0.2313
#
# Document 2177:
# Top words:
# - syntax: 0.5523
# - spell: 0.4898
# - grammar: 0.4843
#
# Document 2178:
# Top words:
# - method: 0.5742
# - alaysz: 0.2401
# - bcg: 0.2401
#
# Document 2179:
# Top words:
# - market: 0.6140
# - compani: 0.2367
# - depart: 0.2015
#
# Document 2180:
# Top words:
# - articl: 0.7272
# - write: 0.1955
# - headlin: 0.1821
#
# Document 2181:
# Top words:
# - sentenc: 0.3911
# - descriptiontag: 0.2820
# - relationship: 0.2688
#
# Document 2182:
# Top words:
# - proofread: 0.4154
# - rephras: 0.3803
# - text: 0.3461
#
# Document 2183:
# Top words:
# - pepper: 0.3992
# - quinoa: 0.3788
# - bell: 0.3497
#
# Document 2184:
# Top words:
# - timstamp: 0.5148
# - creation: 0.3345
# - youtub: 0.3271
#
# Document 2185:
# Top words:
# - product: 0.7019
# - separ: 0.3630
# - articl: 0.3340
#
# Document 2186:
# Top words:
# - fingerpick: 0.4564
# - guitar: 0.4564
# - musicalinstru: 0.4564
#
# Document 2187:
# Top words:
# - messag: 0.4982
# - kind: 0.3911
# - assist: 0.2246
#
# Document 2188:
# Top words:
# - resolut: 0.7731
# - column: 0.2882
# - solut: 0.1877
#
# Document 2189:
# Top words:
# - viewer: 0.3613
# - pari: 0.2441
# - screenwrit: 0.2317
#
# Document 2190:
# Top words:
# - researchtop: 0.3698
# - exampl: 0.3185
# - suggestgiftsag: 0.2465
#
# Document 2191:
# Top words:
# - franchis: 0.3848
# - francis: 0.3848
# - commiss: 0.3653
#
# Document 2192:
# Top words:
# - exercis: 0.3691
# - math: 0.3446
# - option: 0.2903
#
# Document 2193:
# Top words:
# - note: 0.3999
# - clutter: 0.3869
# - transcrib: 0.3869
#
# Document 2194:
# Top words:
# - humanlik: 0.8396
# - style: 0.4649
# - write: 0.2810
#
# Document 2195:
# Top words:
# - meta: 0.5490
# - sure: 0.3325
# - titl: 0.3178
#
# Document 2196:
# Top words:
# - solar: 0.7367
# - instal: 0.2599
# - energi: 0.2565
#
# Document 2197:
# Top words:
# - h: 0.4253
# - head: 0.3080
# - articl: 0.2865
#
# Document 2198:
# Top words:
# - summar: 0.4086
# - text: 0.3761
# - httpsroimindscom: 0.3640
#
# Document 2199:
# Top words:
# - meal: 0.5884
# - app: 0.3644
# - intak: 0.2366
#
# Document 2200:
# Top words:
# - ttulo: 0.3652
# - escreva: 0.3500
# - palavrachav: 0.2679

# %% [markdown]
# ### Potential Rubric
# - Giving the LLM some alias as to assume a new role
# - Mention of anything illegal or sensitive/explicit content
# - Medium as to proxy some sort of illegal request, i.e, a tell a story/script, develop some code, etc.
# - Syntax: Excessive punctuation and longer prompts
# - Prompt Injection: Any mention to ignore or disregard previous instructions
# - AI Simulation: Prompting the LLM to still behave as an AI, but with certain behaviors or additional privileges

# %% [markdown]
# ### Tokenization, BERT Embeddings

# %%
# Load pre-trained BERT tokenizer (to split words into tokens)
tokenizer = BertTokenizer.from_pretrained("bert-base-cased")
# Load pre-trained BERT model (to get BERT embeddings of token sequences)
model = BertModel.from_pretrained("bert-base-cased")

# Input text
sequence_a = "This is a short sequence."
sequence_b = "This is a rather long sequence. It is at least longer than the sequence A."
test_prompts = [sequence_a, sequence_b]

def bert_encode(text):
    inputs = tokenizer(text, padding = True, truncation = True, return_tensors= "pt")
    with torch.no_grad():
        outputs = model(**inputs)
        last_hidden_states = outputs.last_hidden_state

        return last_hidden_states[:, 0, :].numpy()
    
# Print the token IDs
X_bert = bert_encode(sequence_a)
X_bert.shape
# Out:
# c:\Users\Felix\anaconda3\envs\205_final_project\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# (1, 768)

# %%
"""
X_bert = []
counter = 0
for prompt in prompts:
    counter += 1
    bert_encoded_prompt = bert_encode(prompt)
    X_bert.append(list(bert_encoded_prompt[0]))
    if counter % 100 == 0:
        print(counter)

# save the bert encoded prompt inputs 
import pickle

with open('x_bert.pkl', 'wb') as f:
    pickle.dump(X_bert, f)
"""
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200

# %%
# load the X_bert model
with open('x_bert.pkl', 'rb') as f:
    X_bert = pickle.load(f)

X_bert
# Out:
# array([[ 0.42061448, -0.01374823, -0.37611446, ..., -0.44959062,
#          0.3130496 ,  0.25074297],
#        [ 0.44040412, -0.18006052, -0.1318631 , ..., -0.35090825,
#          0.2534349 ,  0.09297992],
#        [ 0.22300643, -0.0667783 , -0.05147534, ..., -0.50410795,
#          0.44083023,  0.3468254 ],
#        ...,
#        [ 0.45422414,  0.09158257,  0.02552419, ..., -0.16662598,
#          0.5531752 ,  0.20425515],
#        [ 0.17053196, -0.07602074, -0.39181766, ..., -0.666373  ,
#          0.23143004,  0.34941292],
#        [ 0.03708125,  0.26739028, -0.14122815, ...,  0.01463655,
#          0.32786667,  0.21163803]], dtype=float32)

# %% [markdown]
# ## Bag of Words

# %%
bag_vectorizer = sklearn.feature_extraction.text.CountVectorizer(tokenizer=tokenize_and_stem)
bag_matrix = bag_vectorizer.fit_transform(prompts)

bag_matrix = bag_matrix.todense()
X_bag = np.asarray(bag_matrix)
# Out:
# c:\Users\Felix\anaconda3\envs\205_final_project\Lib\site-packages\sklearn\feature_extraction\text.py:525: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score

# Step 2: Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(X_tfidf, y, test_size=0.2, random_state=42)

# Step 3: Logistic Regression Model
model = LogisticRegression()
model.fit(X_train, y_train)

# Step 4: Predictions and Evaluation
y_pred = model.predict(X_test)

# Evaluate the model
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9090909090909091
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       0.89      0.93      0.91       213
#         True       0.93      0.89      0.91       227
#
#     accuracy                           0.91       440
#    macro avg       0.91      0.91      0.91       440
# weighted avg       0.91      0.91      0.91       440

# %%
X_train, X_test, y_train, y_test = train_test_split(X_bert, y, test_size=0.2, random_state=42)

# Step 3: Logistic Regression Model
model = LogisticRegression()
model.fit(X_train, y_train)

# Step 4: Predictions and Evaluation
y_pred = model.predict(X_test)

# Evaluate the model
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8954545454545455
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       0.88      0.91      0.89       213
#         True       0.91      0.89      0.90       227
#
#     accuracy                           0.90       440
#    macro avg       0.90      0.90      0.90       440
# weighted avg       0.90      0.90      0.90       440
# c:\Users\Felix\anaconda3\envs\205_final_project\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
X_train, X_test, y_train, y_test = train_test_split(X_bag, y, test_size=0.2, random_state=42)

# Step 3: Logistic Regression Model
model = LogisticRegression()
model.fit(X_train, y_train)

# Step 4: Predictions and Evaluation
y_pred = model.predict(X_test)

# Evaluate the model
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9068181818181819
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       0.87      0.94      0.91       213
#         True       0.94      0.87      0.91       227
#
#     accuracy                           0.91       440
#    macro avg       0.91      0.91      0.91       440
# weighted avg       0.91      0.91      0.91       440

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score

from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier

# arrays to score metrics
bag_train_accuracies = np.array([])
tf_idf_train_accuracies = np.array([])
bert_train_accuracies = np.array([])

bag_test_accuracies = np.array([])
tf_idf_test_accuracies = np.array([])
bert_test_accuracies = np.array([])

# collection of models to test classification with
models = {"Logistic Regression": LogisticRegression(), 
          "LDA": LinearDiscriminantAnalysis(), 
          "SVM": SVC(), 
          "KNN": KNeighborsClassifier(), 
          "Naive Bayes": GaussianNB(), 
          "Decision Tree": DecisionTreeClassifier()}

# collection of datasets to execute the code on
datasets = {"Bag of Words": X_bag, 
            "TF-IDF": X_tfidf, 
            "BERT": X_bert}

# iterate thru each dataset
for dataset_name, dataset in datasets.items():
    # for each dataset, try each classification model
    for model_name, model in models.items():
        # partition the dataset in train/test splits
        X_train, X_test, y_train, y_test = train_test_split(dataset, y, test_size=0.2, random_state=42)
        # model fitting
        model.fit(X_train, y_train)

        # train and test accuracies
        y_test_pred = model.predict(X_test)
        y_train_pred = model.predict(X_train)

        test_accuracy = accuracy_score(y_test, y_test_pred)
        train_accuracy = accuracy_score(y_train, y_train_pred)

        # store the corresponding accuracy value
        if dataset_name == "Bag of Words":
            bag_train_accuracies = np.append(bag_train_accuracies, train_accuracy)
            bag_test_accuracies = np.append(bag_test_accuracies, test_accuracy)
        elif dataset_name == "TF-IDF":
            tf_idf_train_accuracies = np.append(tf_idf_train_accuracies, train_accuracy)
            tf_idf_test_accuracies = np.append(tf_idf_test_accuracies, test_accuracy)
        else:
            bert_train_accuracies = np.append(bert_train_accuracies, train_accuracy)
            bert_test_accuracies = np.append(bert_test_accuracies, test_accuracy)
# Out:
# c:\Users\Felix\anaconda3\envs\205_final_project\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# create dataframes
column_names = list(models.keys())
index_labels = list(datasets.keys())

df_test_accuracies = pd.DataFrame([bag_test_accuracies, tf_idf_test_accuracies, bert_test_accuracies], 
                                  index = index_labels, 
                                  columns = column_names)

df_train_accuracies = pd.DataFrame([bag_train_accuracies, tf_idf_train_accuracies, bert_train_accuracies],
                                   index = index_labels, 
                                  columns = column_names)

# %%
df_train_accuracies
# Out:
#               Logistic Regression       LDA       SVM       KNN  Naive Bayes  \
# Bag of Words             0.995455  0.998864  0.927273  0.851705     0.942045
# TF-IDF                   0.964773  0.998295  0.988068  0.906250     0.959091
# BERT                     0.951136  0.985227  0.886364  0.887500     0.757955
#
#               Decision Tree
# Bag of Words       0.998864
# TF-IDF             0.998864
# BERT               0.997727

# %%
df_test_accuracies
# Out:
#               Logistic Regression       LDA       SVM       KNN  Naive Bayes  \
# Bag of Words             0.906818  0.804545  0.872727  0.779545     0.834091
# TF-IDF                   0.909091  0.809091  0.918182  0.861364     0.843182
# BERT                     0.895455  0.863636  0.875000  0.845455     0.784091
#
#               Decision Tree
# Bag of Words       0.911364
# TF-IDF             0.913636
# BERT               0.811364
